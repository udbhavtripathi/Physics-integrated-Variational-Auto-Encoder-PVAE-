# %% [markdown]
# Van der pol equation:
# $$ m_1{\ddot  {x_1}}+ c_1 {\dot  {x_1}} - k_1 x_1 +  α x_1^3 +c_2({\dot{x_1}}-{\dot{x_2}}) + k_2(x_1-x_2) = \gamma \cos(\omega t)\,$$
#
# $$ m_2{\ddot  {x_2}}+ c_2 ({\dot  {x_2}} - {\dot {x_1}})+ k_2(x_2-x_1) +c_3({\dot{x_2}}-{\dot{x_3}})+ k_3(x_2-x_3)  = \gamma \cos(\omega t)\,$$
#
# $$ m_3{\ddot  {x_3}}+ c_3 ({\dot  {x_3}} - {\dot {x_2}})+ k_3(x_3-x_2)  = \gamma \cos(\omega t)\,$$

# %% [markdown]
# # Initial check

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint  # for comparison
import math
from matplotlib.pyplot import figure
from mpmath import *

# %%
def model(y,t):
    m1 = 3
    m2 = 3
    c1 = 5
    c2 = 5
    k1 = 5
    k2 = 5
    alpha = 0.5
    gamma1 = 5
    gamma2 = 5
    omega1 = 10
    omega2 = 5

    x1, v1, x2, v2 = y[0], y[1], y[2], y[3]

    dx1_dt = v1
    dv1_dt = (gamma1*(math.cos(omega1*t)) -c1*v1 -c2*(v1-v2) -k1*x1 -k2*(x1-x2) -alpha*(x1**3) -alpha*((x1-x2)**3) )/m1

    dx2_dt = v2
    dv2_dt = (gamma2*(math.cos(omega2*t)) -c2*(v2-x1) -k2*(v2-x1) -alpha*((x2-x1)**3) )/m2
    

    return np.array([dx1_dt, dv1_dt, dx2_dt, dv2_dt])

# %%
y0 = [1,0,1,0]

# %%
def rungekutta4(f, y0, t):
    n = len(t)
    y = np.zeros((n, len(y0)))
    y[0] = y0
    for i in range(n - 1):
        h = t[i+1] - t[i]
        k1 = f(y[i], t[i])
        k2 = f(y[i] + k1 * h / 2, t[i] + h / 2)
        k3 = f(y[i] + k2 * h / 2, t[i] + h / 2)
        k4 = f(y[i] + k3 * h, t[i] + h,)
        y[i+1] = y[i] + (h / 6) * (k1 + 2*k2 + 2*k3 + k4)
    return y

# %%
t = np.linspace(0, 50, 500)
sol = rungekutta4(model, y0, t)

# %%
plt.figure()
figure(figsize=(15, 5), dpi=80)
plt.plot(t, sol[:, 0], label='x1')
plt.plot(t, sol[:, 1], label='v1')


plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()

# %%
plt.plot(sol[:,0],sol[:,], label='phase1')


plt.legend(loc='best')
plt.xlabel('x1')
plt.ylabel('v1')
plt.grid()
plt.show()

# %%
plt.plot(t, sol[:, 2], label='x2')
plt.plot(t, sol[:, 3], label='v2')

plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()

# %%
plt.plot(sol[:,2],sol[:,3], label='phase2')


plt.legend(loc='best')
plt.xlabel('x1')
plt.ylabel('v1')
plt.grid()
plt.show()

# %% [markdown]
# # Data Generation

# %%
# !pip install torchdiffeq
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchdiffeq
#   Downloading torchdiffeq-0.2.3-py3-none-any.whl (31 kB)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from torchdiffeq) (1.13.0+cu116)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from torchdiffeq) (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.8/dist-packages (from scipy>=1.4.0->torchdiffeq) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.3.0->torchdiffeq) (4.4.0)
# Installing collected packages: torchdiffeq
# Successfully installed torchdiffeq-0.2.3

# %%
import numpy as np
import scipy.stats as stats
from torchdiffeq import odeint
from scipy.stats import truncnorm
import torch

def generate_traj(init_cond,m1,m2,m3,c1,c2,c3,k1,k2,k3, alpha,gamma,omega, dt, len_episode):

    def ode_sys(t, X):
        x1,v1=torch.Tensor([X[0]]),torch.Tensor([X[1]])
        x2,v2=torch.Tensor([X[2]]),torch.Tensor([X[3]])
        x3,v3=torch.Tensor([X[4]]),torch.Tensor([X[5]])


        dx1_dt = v1
        dv1_dt = torch.Tensor([(gamma*(torch.cos(omega*t)) -c1*v1 + k1*x1 -c2*(v1-v2) -k2*(x1-x2) -alpha*(x1**3)) /m1])

        dx2_dt = v2
        dv2_dt = torch.Tensor([(gamma*(torch.cos(omega*t)) -c2*(v2-v1) - k2*(x2-x1) -c3*(v2-v3) - k3*(x2-x3) ) /m2])

        dx3_dt = v3
        dv3_dt = torch.Tensor([(gamma*(torch.cos(omega*t)) -c3*(v3-v2) - k3*(x3-x2)) /m3])

        

        return torch.cat([dx1_dt, dv1_dt, dx2_dt, dv2_dt,dx3_dt, dv3_dt])

        
    t = torch.Tensor(np.linspace(0.0, dt*(len_episode-1), len_episode))


    #num_sol = odeint(ode_sys, torch.cat([x_init, dxdt_init]), torch.Tensor(t_space)).numpy()
    
    sol = odeint(ode_sys,init_cond,t, method = 'euler').numpy()
    
    return t, sol

# %%
def generate_data(rng, n_samples, range_init_x1,range_init_v1,range_init_x2,range_init_v2,
                  range_init_x3,range_init_v3,range_m1, range_m2,range_m3,
                  range_c1, range_c2,range_c3,range_k1,range_k2, range_k3,
                  range_alpha, range_gamma, range_omega,dt, len_episode, noise_std,
                  bound_x1,bound_v1,bound_m1,bound_c1,bound_k1,bound_x2,bound_v2,bound_m2,bound_c2,bound_k2,
                  bound_x3,bound_v3,bound_m3,bound_c3,bound_k3):
  
      x1_a,x1_b = (bound_x1[0]-range_init_x1[0])/range_init_x1[1] , (bound_x1[1]-range_init_x1[0])/range_init_x1[1]
      v1_a,v1_b = (bound_v1[0]-range_init_v1[0])/range_init_v1[1] , (bound_v1[1]-range_init_v1[0])/range_init_v1[1]
      m1_a,m1_b = (bound_m1[0]-range_m1[0])/range_m1[1] , (bound_m1[1]-range_m1[0])/range_m1[1]
      c1_a,c1_b = (bound_c1[0]-range_c1[0])/range_c1[1] , (bound_c1[1]-range_c1[0])/range_c1[1]
      k1_a,k1_b = (bound_k1[0]-range_k1[0])/range_k1[1] , (bound_k1[1]-range_k1[0])/range_k1[1]

      x2_a,x2_b = (bound_x2[0]-range_init_x2[0])/range_init_x2[1] , (bound_x2[1]-range_init_x2[0])/range_init_x2[1]
      v2_a,v2_b = (bound_v2[0]-range_init_v2[0])/range_init_v2[1] , (bound_v2[1]-range_init_v2[0])/range_init_v2[1]
      m2_a,m2_b = (bound_m2[0]-range_m2[0])/range_m2[1] , (bound_m2[1]-range_m2[0])/range_m2[1]
      c2_a,c2_b = (bound_c2[0]-range_c2[0])/range_c2[1] , (bound_c2[1]-range_c2[0])/range_c2[1]
      k2_a,k2_b = (bound_k2[0]-range_k2[0])/range_k2[1] , (bound_k2[1]-range_k2[0])/range_k2[1]

      x3_a,x3_b = (bound_x3[0]-range_init_x3[0])/range_init_x3[1] , (bound_x3[1]-range_init_x3[0])/range_init_x3[1]
      v3_a,v3_b = (bound_v3[0]-range_init_v3[0])/range_init_v3[1] , (bound_v3[1]-range_init_v3[0])/range_init_v3[1]
      m3_a,m3_b = (bound_m3[0]-range_m3[0])/range_m3[1] , (bound_m3[1]-range_m3[0])/range_m3[1]
      c3_a,c3_b = (bound_c3[0]-range_c3[0])/range_c3[1] , (bound_c3[1]-range_c3[0])/range_c3[1]
      k3_a,k3_b = (bound_k3[0]-range_k3[0])/range_k3[1] , (bound_k3[1]-range_k3[0])/range_k3[1]

      
      init_x1 = torch.Tensor(stats.truncnorm.rvs(x1_a,x1_b,loc=range_init_x1[0], scale=range_init_x1[1], size=n_samples ))
      init_v1 = torch.Tensor(stats.truncnorm.rvs(v1_a,v1_b,loc=range_init_v1[0], scale=range_init_v1[1], size=n_samples ))
      init_x2 = torch.Tensor(stats.truncnorm.rvs(x2_a,x2_b,loc=range_init_x2[0], scale=range_init_x2[1], size=n_samples ))
      init_v2 = torch.Tensor(stats.truncnorm.rvs(v2_a,v2_b,loc=range_init_v2[0], scale=range_init_v2[1], size=n_samples ))
      init_x3 = torch.Tensor(stats.truncnorm.rvs(x3_a,x3_b,loc=range_init_x3[0], scale=range_init_x3[1], size=n_samples ))
      init_v3 = torch.Tensor(stats.truncnorm.rvs(v3_a,v3_b,loc=range_init_v3[0], scale=range_init_v3[1], size=n_samples ))


      m1 = torch.Tensor(stats.truncnorm.rvs(m1_a,m1_b,loc=range_m1[0], scale=range_m1[1], size=n_samples ))
      m2 = torch.Tensor(stats.truncnorm.rvs(m2_a,m2_b,loc=range_m2[0], scale=range_m2[1], size=n_samples ))
      m3 = torch.Tensor(stats.truncnorm.rvs(m3_a,m3_b,loc=range_m3[0], scale=range_m3[1], size=n_samples ))
      #torch.Tensor(stats.truncnorm.rvs(c_a,c_b,loc=range_c[0], scale=range_c[1], size=n_samples ))
      c1 = torch.Tensor(stats.truncnorm.rvs(c1_a,c1_b,loc=range_c1[0], scale=range_c1[1], size=n_samples ))
      c2 = torch.Tensor(stats.truncnorm.rvs(c2_a,c2_b,loc=range_c2[0], scale=range_c2[1], size=n_samples ))
      c3 = torch.Tensor(stats.truncnorm.rvs(c3_a,c3_b,loc=range_c3[0], scale=range_c3[1], size=n_samples ))
      k1 = torch.Tensor(stats.truncnorm.rvs(k1_a,k1_b,loc=range_k1[0], scale=range_k1[1], size=n_samples ))
      k2 = torch.Tensor(stats.truncnorm.rvs(k2_a,k2_b,loc=range_k2[0], scale=range_k2[1], size=n_samples ))
      k3 = torch.Tensor(stats.truncnorm.rvs(k3_a,k3_b,loc=range_k3[0], scale=range_k3[1], size=n_samples ))
      alpha = torch.Tensor(np.random.normal(loc=range_alpha[0], scale=range_alpha[1], size=n_samples))
      gamma = torch.Tensor(np.random.normal(loc=range_gamma[0], scale=range_gamma[1], size=n_samples))
      omega = torch.Tensor(np.random.normal(loc=range_omega[0], scale=range_omega[1], size=n_samples))

      # solve ODE
      x = np.empty((n_samples, len_episode,6))      

      for i in range(n_samples):
          init_cond= torch.cat([init_x1[[i]],init_v1[[i]],init_x2[[i]],init_v2[[i]],init_x3[[i]],init_v3[[i]]])
          t, x_i = generate_traj(init_cond,
                                m1[i],m2[i],m3[i],c1[i],c2[i],c3[i],
                                k1[i],k2[i],k3[i],alpha[i],gamma[i],omega[i], dt, len_episode)
          #print(x_i.shape)
          
          x[i,:,:] = x_i
          #print(x.shape)

      # observation noise
      x = x + rng.normal(loc=0.0, scale=noise_std, size=x.shape)

      return t, x,init_x1,init_v1,init_x2,init_v2,init_x3,init_v3,m1,m2,m3,c1,c2,c3,k1,k2,k3

# %%
# save data
def save_data(name,data):
  np.save('data_{}.npy'.format(name),data)
  print("saved data")

  #np.savetxt('data_{}.txt'.format(name), data)
  

  # # save true parameters
  # np.savetxt('true_params_{}.txt'.format(name),
  #     np.stack([inits, m1,m2,m3,m4,m5,c1,c2,c3,c4,c5,k1,k2,k3,k4,k5,alpha, gamma, omega ], axis=1), fmt='%.9e',
  #     header='inits  m1 m2 m3 m4 m5 c1 c2 c3 c4 c5 k1 k2 k3 k4 k5 alpha gamma omega')
  # print('saved true parameters')

# %%
# len_episode= 400  # time = len_episode * dt
# range_init_x= [0.01,0.002]    
# range_init_v=  [0.01,0.002]  
# range_m= [50,1.25]
# range_c= [20,2] 
# range_k= [1000,150]
# range_alpha= [100,0]
# range_gamma=  [500,0]  
# range_omega= [2.5,0] 
# bound_x = [0.004,0.016]
# bound_v = [0.004,0.016]
# bound_m = [46.25,53.75]
# bound_c = [14,26]
# bound_k = [550,1450]

# %%
len_episode=400  # time = len_episode * dt
range_init_x1= [0.1,0.01]
range_init_v1= [0.1,0.01]
range_init_x2= [0.1,0.01]
range_init_v2= [0.1,0.01]
range_init_x3= [0.2,0.02]
range_init_v3= [0.2,0.02]
range_m1 = [50,2.5]
range_m2 = [50,2.5]
range_m3 = [30,1.5]

range_c1 = [25,2.5]
range_c2 = [25,2.5]
range_c3 = [20,2]

range_k1 = [1000,150]
range_k2 = [1000,150]
range_k3 = [500,75]

range_alpha = [100,0]
range_gamma = [50,0]
range_omega = [10,0]

# %%
bound_x1 = [range_init_x1[0]-3*range_init_x1[1],range_init_x1[0]+3*range_init_x1[1]]
bound_v1 = [range_init_v1[0]-3*range_init_v1[1],range_init_v1[0]+3*range_init_v1[1]]
bound_m1 = [range_m1[0]-3*range_m1[1], range_m1[0]+3*range_m1[1]]
bound_c1 = [range_c1[0]-3*range_c1[1], range_c1[0]+3*range_c1[1]]
bound_k1 = [range_k1[0]-3*range_k1[1], range_k1[0]+3*range_k1[1]]

bound_x2 = [range_init_x2[0]-3*range_init_x2[1],range_init_x2[0]+3*range_init_x2[1]]
bound_v2 = [range_init_v2[0]-3*range_init_v2[1],range_init_v2[0]+3*range_init_v2[1]]
bound_m2 = [range_m2[0]-3*range_m2[1], range_m2[0]+3*range_m2[1]]
bound_c2 = [range_c2[0]-3*range_c2[1], range_c2[0]+3*range_c2[1]]
bound_k2 = [range_k2[0]-3*range_k2[1], range_k2[0]+3*range_k2[1]]

bound_x3 = [range_init_x3[0]-3*range_init_x3[1],range_init_x3[0]+3*range_init_x3[1]]
bound_v3 = [range_init_v3[0]-3*range_init_v3[1],range_init_v3[0]+3*range_init_v3[1]]
bound_m3 = [range_m3[0]-3*range_m3[1], range_m3[0]+3*range_m3[1]]
bound_c3 = [range_c3[0]-3*range_c3[1], range_c3[0]+3*range_c3[1]]
bound_k3 = [range_k3[0]-3*range_k3[1], range_k3[0]+3*range_k3[1]]

# %%
dt=0.01
noise_std=0.001
kwargs = {'range_init_x1': range_init_x1, 'range_init_v1': range_init_v1, 'range_init_x2': range_init_x2, 
          'range_init_v2': range_init_v2,'range_init_x3': range_init_x3,  'range_init_v3': range_init_v3,        

          'range_m1': range_m1,'range_m2': range_m2,'range_m3': range_m3,
          'range_c1': range_c1,'range_c2': range_c2,'range_c3': range_c3,
          'range_k1': range_k1,'range_k2': range_k2,'range_k3': range_k3,
          'range_alpha': range_alpha,'range_gamma': range_gamma,'range_omega': range_omega,          
          'dt': dt, 'len_episode':len_episode, 'noise_std':noise_std,
          'bound_x1':bound_x1, 'bound_v1':bound_v1, 'bound_m1':bound_m1,'bound_c1':bound_c1, 'bound_k1':bound_k1,
          'bound_x2':bound_x2, 'bound_v2':bound_v2, 'bound_m2':bound_m2,'bound_c2':bound_c2, 'bound_k2':bound_k2,
          'bound_x3':bound_x3, 'bound_v3':bound_v3, 'bound_m3':bound_m3,'bound_c3':bound_c3, 'bound_k3':bound_k3}

# %%
## function to choose between training,test and validation data

def data_divider(name):
  if name == "train":
    rng_param=1236
    n_samples=500
    return rng_param,n_samples,name

    
  elif name == "valid":
    rng_param=1235
    n_samples=1
    return rng_param,n_samples,name    
  
  else:
    print("invalid input")

# %%
##Write "train", "test". or "validation for generating data"
rng_param, n_samples,name=data_divider("train")
print(rng_param)
print(n_samples)
print(name)
# Out:
# 1236
# 500
# train

# %%
#generating and saving the data  
t, data,init_x1,init_v1,init_x2,init_v2,init_x3,init_v3,m1,m2,m3,c1,c2,c3, k1,k2,k3,= generate_data(np.random.default_rng(rng_param), n_samples, **kwargs)
#saving data
save_data(name, data)
# Out:
# saved data

# %% [markdown]
# storing min-max values

# %%
data_params = np.loadtxt('true_params_train.txt')
data_params.shape
# Out:
# (500, 18)

# %%
init_x1 = data_params[:,0]
init_v1 =data_params[:,1]
init_x2 =data_params[:,2]
init_v2=data_params[:,3] 
init_x3 =data_params[:,4]
init_v3 =data_params[:,5]


m1 =data_params[:,6]
m2 =data_params[:,7]
m3 =data_params[:,8]

c1 =data_params[:,9]
c2 =data_params[:,10]
c3 =data_params[:,11]

k1 =data_params[:,12]
k2 =data_params[:,13]
k3 =data_params[:,14]

alpha =data_params[:,15]
gamma =data_params[:,16]
omega =data_params[:,17]

# %%
x1_o_min = init_x1.min()
x1_o_max = init_x1.max() 
v1_o_min = init_v1.min()
v1_o_max = init_v1.max() 
x2_o_min = init_x2.min()
x2_o_max = init_x2.max() 
v2_o_min = init_v2.min()
v2_o_max = init_v2.max() 
x3_o_min = init_x3.min()
x3_o_max = init_x3.max() 
v3_o_min = init_v3.min()
v3_o_max = init_v3.max() 


m1_o_min = m1.min()
m1_o_max = m1.max()
m2_o_min = m2.min()
m2_o_max = m2.max()
m3_o_min = m3.min()
m3_o_max = m3.max()


c1_o_min = c1.min()
c1_o_max = c1.max()
c2_o_min = c2.min()
c2_o_max = c2.max()
c3_o_min = c3.min()
c3_o_max = c3.max()


k1_o_min = k1.min()
k1_o_max = k1.max()
k2_o_min = k2.min()
k2_o_max = k2.max()
k3_o_min = k3.min()
k3_o_max = k3.max()

# %%
##Write "train", "test". or "validation for generating data"
rng_param, n_samples,name=data_divider("valid")
print(rng_param)
print(n_samples)
print(name)
# Out:
# 1235
# 1
# valid

# %%
#generating and saving the data  
tv, datav,init_x1v,init_v1v,init_x2v,init_v2v,init_x3v,init_v3v,m1v,m2v,m3v,c1v,c2v,c3v, k1v,k2v,k3v= generate_data(np.random.default_rng(rng_param), n_samples, **kwargs)
#saving data
save_data(name, data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8ef4efbb3a80> in <module>
#       2 tv, datav,init_x1v,init_v1v,init_x2v,init_v2v,init_x3v,init_v3v,m1v,m2v,m3v,c1v,c2v,c3v, k1v,k2v,k3v= generate_data(np.random.default_rng(rng_param), n_samples, **kwargs)
#       3 #saving data
# ----> 4 save_data(name, data)
#
# NameError: name 'data' is not defined

# %%
data_train_1 = np.load('data_train.npy')

# %%
data_train_dis1 = data_train_1[:,:,0]

data_train_dis2 = data_train_1[:,:,2]

data_train_dis3 = data_train_1[:,:,4]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
t = np.linspace(0.0, 4,400)
# show
idx =0
plt.figure()
figure(figsize=(15, 10), dpi=80)
for i in range(10):
    plt.plot(t,data_train_dis1[i])
    #plt.plot(t,data_train_vel1[i])
    
    #plt.ylim([-2.0, 2.0])
plt.legend(loc='upper right',fontsize=10)
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
# t = np.linspace(0.0, 2.5, 50)
# show
idx =0
plt.figure()
figure(figsize=(15, 10), dpi=80)

for i in range(10):
    plt.plot(t,data_train_dis2[i])
    #plt.plot(t,data_train_vel2[i])
    
    #plt.ylim([-2.0, 2.0])
plt.legend(loc='upper right',fontsize=10)
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
#t = np.linspace(0.0, 2.5, 50)
# show
idx =0
plt.figure()
figure(figsize=(15, 10), dpi=80)

for i in range(10):
    plt.plot(t,data_train_dis3[i])
    #plt.plot(t,data_train_vel3[i])
    
    #plt.ylim([-2.0, 2.0])
plt.legend(loc='upper right',fontsize=10)
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
cf_x1_true_dis_std =[]
cf_x1_true_dis_T = data_train_dis1.T
for y in cf_x1_true_dis_T:
   #print(x.shape)
    cf_x1_true_dis_std.append(y.var())

cf_x2_true_dis_std =[]
cf_x2_true_dis_T = data_train_dis2.T
for y in cf_x2_true_dis_T:
   #print(x.shape)
    cf_x2_true_dis_std.append(y.var())


cf_x3_true_dis_std =[]
cf_x3_true_dis_T = data_train_dis3.T
for y in cf_x3_true_dis_T:
   #print(x.shape)
    cf_x3_true_dis_std.append(y.var())

# %%
plt.plot(t,cf_x1_true_dis_std,color='blue',linestyle='dashed',linewidth =3 ,label="Ground Truth variance")

# %%
plt.plot(t,cf_x2_true_dis_std,color='blue',linestyle='dashed',linewidth =3 ,label="Ground Truth variance")

# %%
plt.plot(t,cf_x3_true_dis_std,color='blue',linestyle='dashed',linewidth =3 ,label="Ground Truth variance")

# %% [markdown]
# # Normalizing data

# %%
x1_new = (init_x1-x1_o_min)/(x1_o_max - x1_o_min)
v1_new = (init_v1-v1_o_min)/(v1_o_max - v1_o_min)
m1_new = (m1-m1_o_min)/(m1_o_max - m1_o_min)
c1_new = (c1-c1_o_min)/(c1_o_max - c1_o_min)
k1_new = (k1-k1_o_min)/(k1_o_max - k1_o_min)

x2_new = (init_x2-x2_o_min)/(x2_o_max - x2_o_min)
v2_new = (init_v2-v2_o_min)/(v2_o_max - v2_o_min)
m2_new = (m2-m2_o_min)/(m2_o_max - m2_o_min)
c2_new = (c2-c2_o_min)/(c2_o_max - c2_o_min)
k2_new = (k2-k2_o_min)/(k2_o_max - k2_o_min)

x3_new = (init_x3-x3_o_min)/(x3_o_max - x3_o_min)
v3_new = (init_v3-v3_o_min)/(v3_o_max - v3_o_min)
m3_new = (m3-m3_o_min)/(m3_o_max - m3_o_min)
c3_new = (c3-c3_o_min)/(c3_o_max - c3_o_min)
k3_new = (k3-k3_o_min)/(k3_o_max - k3_o_min)

# %%
x1_mean = x1_new.mean() 
x1_std = x1_new.std()
v1_mean = v1_new.mean() 
v1_std = v1_new.std()
m1_mean = m1_new.mean() 
m1_std = m1_new.std()
c1_mean = c1_new.mean() 
c1_std = c1_new.std()
k1_mean = k1_new.mean() 
k1_std = k1_new.std()


x2_mean = x2_new.mean() 
x2_std = x2_new.std()
v2_mean = v2_new.mean() 
v2_std = v2_new.std()
m2_mean = m2_new.mean() 
m2_std = m2_new.std()
c2_mean = c2_new.mean() 
c2_std = c2_new.std()
k2_mean = k2_new.mean() 
k2_std = k2_new.std()


x3_mean = x3_new.mean() 
x3_std = x3_new.std()
v3_mean = v3_new.mean() 
v3_std = v3_new.std()
m3_mean = m3_new.mean() 
m3_std = m3_new.std()
c3_mean = c3_new.mean() 
c3_std = c3_new.std()
k3_mean = k3_new.mean() 
k3_std = k3_new.std()

# %%
lower_x1 = x1_new.min()
upper_x1 = x1_new.max() 
lower_v1 = v1_new.min()
upper_v1 = v1_new.max() 
lower_m1 = 1e-6
upper_m1 = m1_new.max() 
lower_c1 = c1_new.min() 
upper_c1 = c1_new.max() 
lower_k1 = k1_new.min() 
upper_k1 = k1_new.max() 

lower_x2 = x2_new.min()
upper_x2 = x2_new.max() 
lower_v2 = v2_new.min()
upper_v2 = v2_new.max() 
lower_m2 = 1e-6
upper_m2 = m2_new.max() 
lower_c2 = c2_new.min() 
upper_c2 = c2_new.max() 
lower_k2 = k2_new.min() 
upper_k2 = k2_new.max() 

lower_x3 = x3_new.min()
upper_x3 = x3_new.max() 
lower_v3 = v3_new.min()
upper_v3 = v3_new.max() 
lower_m3 = 1e-6
upper_m3 = m3_new.max() 
lower_c3 = c3_new.min() 
upper_c3 = c3_new.max() 
lower_k3 = k3_new.min() 
upper_k3 = k3_new.max()

# %% [markdown]
# # Load data

# %%
data_train_1.shape
# Out:
# (500, 400, 6)

# %%
import numpy as np

data_train_1 = np.load('data_train.npy')

data_train_dis1 = data_train_1[:,:,0]
data_train_dis2 = data_train_1[:,:,2]
data_train_dis3 = data_train_1[:,:,4]

# %%
# load training/validation data for 1st DOF
data_valid_1 = np.load('data_valid.npy')


data_valid_dis1 = data_valid_1[:,:,0]
data_valid_dis2 = data_valid_1[:,:,2]
data_valid_dis3 = data_valid_1[:,:,4]

# %% [markdown]
# # Helper functions

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt


def actmodule(activation:str):
    if activation == 'softplus':
        return nn.Softplus()
    elif activation == 'relu':
        return nn.ReLU()
    elif activation == 'leakyrelu':
        return nn.LeakyReLU()
    elif activation == 'prelu':
        return nn.PReLU()
    elif activation == 'elu':
        return nn.ELU()
    elif activation == 'tanh':
        return nn.Tanh()
    else:
        raise ValueError('unknown activation function specified')



def kernel_mat_gauss(sample:torch.Tensor, width:float):
    # https://discuss.pytorch.org/t/efficient-distance-matrix-computation/9065/
    #euclidean norm
    norm = (sample**2).sum(1).view(-1, 1)
    #distance matrix
    dist_mat = norm + norm.view(1,-1) - 2.0 * torch.mm(sample, torch.transpose(sample,0,1))
    dist_mat[dist_mat != dist_mat] = 0.0
    # width = torch.max(torch.ones(1,device=sample.device)*1e-4, torch.median(dist_mat).detach())
    return torch.exp(-dist_mat / width)



def hsic(kmat1:torch.Tensor, kmat2:torch.Tensor):
    """
    Unbiased estimator of HSIC [Song+ ICML 2007]
    """
    m = kmat1.shape[0]
    assert m>3
    device = kmat1.device
    K1 = (1.0 - torch.eye(m, device=device)) * kmat1
    K2 = (1.0 - torch.eye(m, device=device)) * kmat2
    return ( torch.sum(K1*K2.T) + torch.sum(K1)*torch.sum(K2)/(m-1)/(m-2) \
            - torch.sum(torch.sum(K1,dim=0)*torch.sum(K2,dim=1))*2/(m-2) ) / m / (m-3)



def mmd(kmat11:torch.Tensor, kmat22:torch.Tensor, kmat12:torch.Tensor):
    """
    Estimator of MMD
    """
    m1 = kmat11.shape[0]
    m2 = kmat22.shape[0]
    return torch.sum(kmat11)/m1/m1 + torch.sum(kmat22)/m2/m2 - 2.0*torch.sum(kmat12)/m1/m2


def nll_normal(data:torch.Tensor, mean:torch.Tensor, lnvar:torch.Tensor):
    """
    Negative log likelihood based on normal observation model, -log N(data | mean1, diag(exp(lnvar)))
    """
    d = data.shape[1]
    if lnvar.ndim==2:
        nll = 0.5*d*1.8379 + 0.5*torch.sum((data-mean).pow(2)/lnvar.exp(), dim=1) + 0.5*torch.sum(lnvar, dim=1)
    else:
        nll = 0.5*d*1.8379 + 0.5*torch.sum((data-mean).pow(2), dim=1)/lnvar.exp() + 0.5*d*lnvar
    return nll



def kldiv_logits_logits(logits1:torch.Tensor, logits2:torch.Tensor):
    """
    KL divergence between categorical distributions represented by sets of logits
    """
    # KL(q(z_phy|x) or p(z_phy) || p(z_phy))
    #   = \sum_i q_i (logit_q_i - logit_p_i) - (lse(logits_q) - lse(logits_p))
    logits1_logsumexp = torch.logsumexp(logits1, dim=1)
    logits2_logsumexp = torch.logsumexp(logits2, dim=1)
    probs1 = torch.exp(logits1 - logits1_logsumexp.unsqueeze(1))
    return torch.sum(probs1 * (logits1-logits2), dim=1) - (logits1_logsumexp-logits2_logsumexp)



def kldiv_normal_normal(mean1:torch.Tensor, lnvar1:torch.Tensor, mean2:torch.Tensor, lnvar2:torch.Tensor):
    """
    KL divergence between normal distributions, KL( N(mean1, diag(exp(lnvar1))) || N(mean2, diag(exp(lnvar2))) )
    """
    if lnvar1.ndim==2 and lnvar2.ndim==2:

        return 0.5 * torch.sum((lnvar1-lnvar2).exp() - 1.0 + lnvar2 - lnvar1 + (mean2-mean1).pow(2)/lnvar2.exp(), dim=1)
        
    elif lnvar1.ndim==1 and lnvar2.ndim==1:
        d = mean1.shape[1]
        return 0.5 * (d*((lnvar1-lnvar2).exp() - 1.0 + lnvar2 - lnvar1) + torch.sum((mean2-mean1).pow(2), dim=1)/lnvar2.exp())
    else:
        raise ValueError()



def pdfratio_normal(data:torch.Tensor, mean1:torch.Tensor, lnvar1:torch.Tensor, mean2:torch.Tensor, lnvar2:torch.Tensor):
    """
    Value of ratio of pdfs, N(mean1, diag(exp(lnvar1))) / N(mean2, diag(exp(lnvar2)))
    """
    lnpdf1 = -nll_normal(data, mean1, lnvar1)
    lnpdf2 = -nll_normal(data, mean2, lnvar2)
    return torch.exp(lnpdf1 - lnpdf2)


def draw_normal(mean:torch.Tensor, lnvar:torch.Tensor):
    std = torch.exp(0.5*lnvar)
    eps = torch.randn_like(std) # reparametrization trick
    return mean + eps*std


#for plotting 

def set_default(figsize=(0, 10), dpi=100):    
    plt.rc('axes', facecolor='white')
    plt.rc('figure', facecolor='white')
    plt.rc('figure', figsize=figsize, dpi=dpi)

# %% [markdown]
# # Define device

# %%
cuda = True and torch.cuda.is_available()
device = torch.device("cuda")
device
# Out:
# device(type='cuda')

# %% [markdown]
# # MLP

# %%
import torch
import torch.nn as nn

#from . import utils
# import utils


class MLP(nn.Module):
    """Multi-layer perceptron.
    """
    def __init__(self, dims_all:list, activation:str,
                 dropout:float=0.3, batchnorm:bool=False, actfun_output:bool=False, binary_output:bool=False):
        super(MLP, self).__init__()

        modules = []

        # from first to second-last layer
        for i in range(len(dims_all)-2):
            # fully-connected
            modules.append(nn.Linear(dims_all[i], dims_all[i+1]))
            # batch normalization if any
            if batchnorm:
                modules.append(nn.BatchNorm1d(dims_all[i+1]))
            # nonlinear activation
            modules.append(activation)
            # dropout if any
            if dropout>0.0:
                modules.append(nn.Dropout(p=dropout))

        # last layer
        modules.append(nn.Linear(dims_all[-2], dims_all[-1]))
        if actfun_output:
            modules.append(activation)
        if binary_output:
            modules.append(nn.Sigmoid())

        self.net = nn.Sequential(*modules)
        self.dim_in = dims_all[0]


    def forward(self, x:torch.Tensor):
        out = self.net(x.view(-1, self.dim_in))
        return out

# %% [markdown]
# # VAE: Displacement 3

# %%
import torch
from torch import nn
from torch.nn import functional as F

from torchdiffeq import odeint


class Decoders_dis3(nn.Module):
    def __init__(self,config_dis3):
        super(Decoders_dis3, self).__init__()

        dim_t = config_dis3['dim_t']
        
        dim_z_aux9 = config_dis3['dim_z_aux9']
        dim_z_aux10 = config_dis3['dim_z_aux10']
        activation = config_dis3['activation']
        no_phy = config_dis3['no_phy']
        x_lnvar = config_dis3['x_lnvar']        

        # x_lnvar
        self.register_buffer('param_x_lnvar', torch.ones(1)*x_lnvar)

        if dim_z_aux9 >= 0:
            hidlayers_aux1 = config_dis3['hidlayers_aux1_dec']

            # z_aux1, yy (=[y, y_dot]) & t --> time-derivative of y_dot
            #(dim_z_aux9 + 2+1, 1)            
            self.func_aux9 = MLP([dim_z_aux9+2+1,]+hidlayers_aux1+[1,], activation)

        if dim_z_aux10 >= 0:
            hidlayers_aux2 = config_dis3['hidlayers_aux2_dec']
            # z_phy, z_aux2 --> x - y_seq
            dim_z_phy = 0 if no_phy else 5    #(m3,c3,k3,init_x3,init_v3)
            self.func_aux10_res = MLP([dim_z_phy+max(0,dim_z_aux9)+dim_z_aux10,]+hidlayers_aux2+[dim_t,], activation)



class Encoders_dis3(nn.Module):
    def __init__(self, config_dis3):
        super(Encoders_dis3, self).__init__()

        dim_t = config_dis3['dim_t']
        
        dim_z_aux9 = config_dis3['dim_z_aux9']
        dim_z_aux10 = config_dis3['dim_z_aux10']
        activation = config_dis3['activation']
        no_phy = config_dis3['no_phy']
        num_units_feat = config_dis3['num_units_feat']

        if dim_z_aux9 > 0:
            hidlayers_aux1_enc = config_dis3['hidlayers_aux1_enc']

            # x --> feature_aux9
            self.func_feat_aux9 = FeatureExtractor(config_dis3)

            # feature_aux9 --> z_aux1
            self.func_z_aux9_mean = MLP([num_units_feat,]+hidlayers_aux1_enc+[dim_z_aux9,], activation)
            self.func_z_aux9_lnvar = MLP([num_units_feat,]+hidlayers_aux1_enc+[dim_z_aux9,], activation)

        if dim_z_aux10 > 0:
            hidlayers_aux2_enc = config_dis3['hidlayers_aux2_enc']

            # x --> feature_aux10
            self.func_feat_aux10 = FeatureExtractor(config_dis3)

            # feature_aux10 --> z_aux2
            self.func_z_aux10_mean = MLP([num_units_feat,]+hidlayers_aux2_enc+[dim_z_aux10,], activation)
            self.func_z_aux10_lnvar = MLP([num_units_feat,]+hidlayers_aux2_enc+[dim_z_aux10,], activation)

        if not no_phy:
            hidlayers_unmixer = config_dis3['hidlayers_unmixer']
            
            hidlayers_m3 = config_dis3['hidlayers_m3']
            hidlayers_c3 = config_dis3['hidlayers_c3']
            hidlayers_k3 = config_dis3['hidlayers_k3']

            hidlayers_init_x3 = config_dis3['hidlayers_init_x3']
            hidlayers_init_v3 = config_dis3['hidlayers_init_v3']
      

            # x, z_aux1, z_aux2 --> unmixed - x
            self.func_unmixer_res = MLP([dim_t+max(dim_z_aux9,0)+max(dim_z_aux10,0),]+hidlayers_unmixer+[dim_t,], activation)
           

            # unmixed --> feature_phy
            self.func_feat_phy = FeatureExtractor(config_dis3)

            # features_phy --> m3
            self.func_m3_mean = nn.Sequential(MLP([num_units_feat,]+hidlayers_m3+[1,], activation), nn.Softplus())
            self.func_m3_lnvar = MLP([num_units_feat,]+hidlayers_m3+[1,], activation)

            # features_phy --> c1
            self.func_c3_mean = nn.Sequential(MLP([num_units_feat,]+hidlayers_c3+[1,], activation), nn.Softplus())
            self.func_c3_lnvar = MLP([num_units_feat,]+hidlayers_c3+[1,], activation)

            # features_phy --> k1
            self.func_k3_mean = nn.Sequential(MLP([num_units_feat,]+hidlayers_k3+[1,], activation), nn.Softplus())
            self.func_k3_lnvar = MLP([num_units_feat,]+hidlayers_k3+[1,], activation)

            # features_phy --> init_x3
            self.func_init_x3_mean = nn.Sequential(MLP([num_units_feat,]+hidlayers_init_x3+[1,], activation), nn.Softplus())
            self.func_init_x3_lnvar = MLP([num_units_feat,]+hidlayers_init_x3+[1,], activation)

            # features_phy --> init_v3
            self.func_init_v3_mean = nn.Sequential(MLP([num_units_feat,]+hidlayers_init_v3+[1,], activation), nn.Softplus())
            self.func_init_v3_lnvar = MLP([num_units_feat,]+hidlayers_init_v3+[1,], activation)

      


class FeatureExtractor(nn.Module):
    def __init__(self, config_dis3):
        super(FeatureExtractor, self).__init__()

        dim_t = config_dis3['dim_t']
        activation = config_dis3['activation']
        arch_feat = config_dis3['arch_feat']
        num_units_feat = config_dis3['num_units_feat']

        self.dim_t = dim_t
        self.arch_feat = arch_feat
        self.num_units_feat = num_units_feat

        if arch_feat=='mlp':
            hidlayers_feat = config_dis3['hidlayers_feat']

            self.func= MLP([dim_t,]+hidlayers_feat+[num_units_feat,], activation, actfun_output=True)
        elif arch_feat=='rnn':
            num_rnns_feat = config_dis3['num_rnns_feat']

            self.num_rnns_feat = num_rnns_feat
            self.func = nn.GRU(1, num_units_feat, num_layers=num_rnns_feat, bidirectional=False)
        else:
            raise ValueError('unknown feature type')

    def forward(self, x:torch.Tensor):
        x_ = x.view(-1, self.dim_t)
        n = x_.shape[0]
        device = x_.device

        if self.arch_feat=='mlp':
            feat = self.func(x_)
        elif self.arch_feat=='rnn':
            h_0 = torch.zeros(self.num_rnns_feat, n, self.num_units_feat,device = device)
            out, h_n = self.func(x_.T.unsqueeze(2), h_0)
            feat = out[-1]

        return feat



class Physics(nn.Module):
    def __init__(self):
        super(Physics, self).__init__()

    def forward(self, m3:torch.Tensor, c3:torch.Tensor,k3:torch.Tensor,t:torch.Tensor, yy:torch.Tensor):
        m3dn = m3 * (m3_o_max - m3_o_min) + m3_o_min
        c3dn = c3 * (c3_o_max - c3_o_min) + c3_o_min
        k3dn = k3 * (k3_o_max - k3_o_min) + k3_o_min

        gamma = config_dis3['gamma']
        omega = config_dis3['omega']
        force = gamma * torch.cos(omega*t)

        return torch.cat([yy[:,1].reshape(-1,1), (force -c3dn*(yy[:,1].view(-1,1)) - k3dn*(yy[:,0].view(-1,1)))/m3dn], dim=1)




class VAE_dis3(nn.Module):
    def __init__(self, config_dis3):
        super(VAE_dis3, self).__init__()        

        self.dim_t = config_dis3['dim_t']        
        self.dim_z_aux9 = config_dis3['dim_z_aux9']
        self.dim_z_aux10 = config_dis3['dim_z_aux10']
 
        self.range_m3 = config_dis3['range_m3']
        self.range_c3 = config_dis3['range_c3']
        self.range_k3 = config_dis3['range_k3']
        self.range_init_x3 = config_dis3['range_init_x3']
        self.range_init_v3 = config_dis3['range_init_v3']
        self.activation = config_dis3['activation']
        self.dt = config_dis3['dt']
        self.intg_lev = config_dis3['intg_lev']
        self.ode_solver = config_dis3['ode_solver']
        self.no_phy = config_dis3['no_phy']

        # Decoding part
        self.dec_dis3 = Decoders_dis3(config_dis3)

        # Encoding part
        self.enc_dis3 = Encoders_dis3(config_dis3)

        # Physics
        self.physics_model = Physics()

        # set time indices for integration
        self.dt_intg = self.dt / float(self.intg_lev)
        self.len_intg = (self.dim_t - 1) * self.intg_lev + 1

        
        self.register_buffer('t_intg', torch.linspace(0.0, self.dt_intg*(self.len_intg-1), self.len_intg))
        

    # def priors(self, n:int, device:torch.device):

    #     prior_c3_stat = {'mean': torch.ones(n,1,device = device) * 0.5 * (self.range_c3[0] + self.range_c3[1]),
    #         'lnvar': 2.0*torch.log( torch.ones(n,1,device = device) * max(1e-3, 0.866*(self.range_c3[1] - self.range_c3[0])) )}
    #     prior_k3_stat = {'mean': torch.ones(n,1,device = device) * 0.5 * (self.range_k3[0] + self.range_k3[1]),
    #         'lnvar': 2.0*torch.log( torch.ones(n,1,device = device) * max(1e-3, 0.866*(self.range_k3[1] - self.range_k3[0])) )}
    #     prior_c4_stat = {'mean': torch.ones(n,1,device = device) * 0.5 * (self.range_c4[0] + self.range_c4[1]),
    #         'lnvar': 2.0*torch.log( torch.ones(n,1,device = device) * max(1e-3, 0.866*(self.range_c4[1] - self.range_c4[0])) )}
    #     prior_k4_stat = {'mean': torch.ones(n,1,device = device) * 0.5 * (self.range_k4[0] + self.range_k4[1]),
    #         'lnvar': 2.0*torch.log( torch.ones(n,1,device = device) * max(1e-3, 0.866*(self.range_k4[1] - self.range_k4[0])) )}
    #     prior_init_x3_stat = {'mean': torch.ones(n,1,device = device) * 0.5 * (self.range_init_x3[0] + self.range_init_x3[1]),
    #         'lnvar': 2.0*torch.log( torch.ones(n,1,device = device) * max(1e-3, 0.866*(self.range_init_x3[1] - self.range_init_x3[0])) )}
    #     prior_z_aux9_stat = {'mean': torch.zeros(n, max(0,self.dim_z_aux9),device = device),
    #         'lnvar': torch.zeros(n, max(0,self.dim_z_aux9),device = device)}
    #     prior_z_aux10_stat = {'mean': torch.zeros(n, max(0,self.dim_z_aux10),device = device),
    #         'lnvar': torch.zeros(n, max(0,self.dim_z_aux10),device = device)}

    #     return prior_c3_stat,prior_k3_stat,prior_c4_stat,prior_k4_stat,prior_init_x3_stat, prior_z_aux9_stat, prior_z_aux10_stat




    def priors(self, n:int, device:torch.device):
        prior_m3_stat = {'mean': torch.ones(n,1,device = device) * (self.range_m3[0]),
            'lnvar': 2.0*torch.log( torch.ones(n,1,device = device) * (self.range_m3[1] ) )}
        prior_c3_stat = {'mean': torch.ones(n,1,device = device) * (self.range_c3[0]),
            'lnvar': 2.0*torch.log( torch.ones(n,1,device = device) * (self.range_c3[1] ) )}
        prior_k3_stat = {'mean': torch.ones(n,1,device = device) * (self.range_k3[0]),
            'lnvar': 2.0*torch.log( torch.ones(n,1,device = device) * (self.range_k3[1] ) )}
        
        prior_init_x3_stat = {'mean': torch.ones(n,1,device = device) * (self.range_init_x3[0] ),
            'lnvar': 2.0*torch.log( torch.ones(n,1,device = device) * (self.range_init_x3[1] ) )}
        prior_init_v3_stat = {'mean': torch.ones(n,1,device = device) * (self.range_init_v3[0] ),
            'lnvar': 2.0*torch.log( torch.ones(n,1,device = device) * (self.range_init_v3[1] ) )}
        prior_z_aux9_stat = {'mean': torch.zeros(n, max(0,self.dim_z_aux9),device = device),
            'lnvar': torch.zeros(n, max(0,self.dim_z_aux9),device = device)}
        prior_z_aux10_stat = {'mean': torch.zeros(n, max(0,self.dim_z_aux10),device = device),
            'lnvar': torch.zeros(n, max(0,self.dim_z_aux10),device = device)}

        return prior_m3_stat,prior_c3_stat,prior_k3_stat,prior_init_x3_stat,prior_init_v3_stat, prior_z_aux9_stat, prior_z_aux10_stat


    def generate_physonly(self,m3:torch.Tensor,c3:torch.Tensor,k3:torch.Tensor,init_x3:torch.Tensor, init_v3:torch.Tensor):
        n = init_x3.shape[0]  
        device = init_x3.device      

        # define ODE        
        def ODEfunc(t:torch.Tensor, yy:torch.Tensor):
            return self.physics_model(m3,c3,k3,t, yy)

        # solve ODE
        x3dn = init_x3 * (x3_o_max - x3_o_min) + x3_o_min
        v3dn = init_v3 * (v3_o_max - v3_o_min) + v3_o_min
    
        initcond = torch.cat([x3dn,v3dn], dim=1) # <n x 2>
        yy_seq = odeint(ODEfunc, initcond, self.t_intg,method=self.ode_solver ) # <len_intg x n x 2>

        return yy_seq


    def decode(self,m3:torch.Tensor,c3:torch.Tensor, k3:torch.Tensor,init_x3:torch.Tensor,init_v3:torch.Tensor, z_aux9:torch.Tensor, z_aux10:torch.Tensor, full:bool=False):
        n = init_x3.shape[0]     
        device = init_x3.device  

        # define ODE
        
        def ODEfunc(t:torch.Tensor, _yy:torch.Tensor):
            """Gives gradient of vector _yy, whose shape is <n x 4> or <n x 2>.
            - t should be a scalar
            - _yy should be shape <n x 4> or <n x 2>
            """

            yy_PA = _yy[:, [0,1]]
            if full:
                yy_P = _yy[:, [2,3]]

            if not self.no_phy:
                # physics part (c3,k3,c4,k4 & yy --> time-deriv of yy)
                yy_dot_phy_PA = self.physics_model(m3,c3,k3 ,t,yy_PA)
                if full:
                    yy_dot_phy_P = self.physics_model(m3,c3,k3,t,yy_P)
            else:
                # when model has no physics part *originally*
                yy_dot_phy_PA = torch.zeros(n, 2,device = device)
                if full:
                    yy_dot_phy_P = torch.zeros(n, 2,device = device)


            if self.dim_z_aux9 >= 0: 
                # in-ODE auxiliary part (z_aux1, yy & t --> time-deriv of y_dot)
                yy_dot_aux_PA = torch.cat([torch.zeros(n,1,device = device),
                    self.dec_dis3.func_aux9(torch.cat([z_aux9, yy_PA, t.expand(n,1)], dim=1))], dim=1)


            else:
                # when model has no in-ODE auxiliary part *originally*
                yy_dot_aux_PA = torch.zeros(n, 2,device = device)
    

            if full:
                return torch.cat([yy_dot_phy_PA+yy_dot_aux_PA, yy_dot_phy_P], dim=1)
            else:
                return torch.cat([yy_dot_phy_PA+yy_dot_aux_PA], dim=1)

        # solve
        x3dn = init_x3 * (x3_o_max - x3_o_min) + x3_o_min
        v3dn = init_v3 * (v3_o_max - v3_o_min) + v3_o_min
        if full:
            initcond = torch.cat([x3dn,v3dn,x3dn,v3dn], dim=1) # <n x 4>
        else:
            initcond = torch.cat([x3dn,v3dn], dim=1) # <n x 2>
            
        yy_seq = odeint(ODEfunc, initcond,self.t_intg,method=self.ode_solver) # <len_intg x n x 2or4>
        
        yy_seq = yy_seq[range(0, self.len_intg, self.intg_lev)] # subsample to <dim_t x n x 2or4>

        # extract to <n x dim_t>
        y_seq_PA = yy_seq[:,:,0].T
        if full:
            y_seq_P = yy_seq[:,:,2].T

        # out-ODE auxiliary part (y_seq, z_aux2 --> x)
        x_PA = y_seq_PA; x_PAB = x_PA.clone()
        if full:
            x_P = y_seq_P; x_PB = x_P.clone()
        if self.dim_z_aux10 >= 0:

            x_PAB += self.dec_dis3.func_aux10_res(torch.cat((m3,c3,k3,init_x3,init_v3, z_aux9, z_aux10), dim=1))
            #x_PAB = (x_PAB - data_train_dis3_us_min)/(data_train_dis3_us_max-data_train_dis3_us_min)
            # dec2_out = self.dec_dis3.func_aux10_res(torch.cat((m3,c3,k3,init_x3,init_v3, z_aux9, z_aux10), dim=1))
            # dec2_out = (dec2_out -data_train_dis3_us_min)/(data_train_dis3_us_max-data_train_dis3_us_min)
            # x_PAB += dec2_out


            if full:
                x_PB += self.dec_dis3.func_aux10_res(torch.cat((m3,c3,k3,init_x3, init_v3,z_aux9, z_aux10), dim=1))

        if full:
            
            return x_PAB, x_PA, x_PB, x_P, self.dec_dis3.param_x_lnvar
        else:

            return x_PAB, self.dec_dis3.param_x_lnvar


    def encode(self, x:torch.Tensor):
        x_ = x.view(-1, self.dim_t)
        n = x_.shape[0]
        device = x_.device      

        # infer z_aux9, z_aux10
        if self.dim_z_aux9 > 0:
            feature_aux9 = self.enc_dis3.func_feat_aux9(x_)
            z_aux9_stat = {'mean':self.enc_dis3.func_z_aux9_mean(feature_aux9), 'lnvar':self.enc_dis3.func_z_aux9_lnvar(feature_aux9)}
        else:
            z_aux9_stat = {'mean':torch.empty(n, 0,device= device), 'lnvar':torch.empty(n, 0,device= device)}

        if self.dim_z_aux10 > 0:
            feature_aux10 = self.enc_dis3.func_feat_aux10(x_)
            z_aux10_stat = {'mean':self.enc_dis3.func_z_aux10_mean(feature_aux10), 'lnvar':self.enc_dis3.func_z_aux10_lnvar(feature_aux10)}
        else:
            z_aux10_stat = {'mean':torch.empty(n, 0,device= device), 'lnvar':torch.empty(n, 0,device= device)}

        # infer phy_parameter
        if not self.no_phy:
            # unmixing
            unmixed = x_ + self.enc_dis3.func_unmixer_res(torch.cat((x_, z_aux9_stat['mean'], z_aux10_stat['mean']), dim=1))
           
            # after unmixing
            feature_phy = self.enc_dis3.func_feat_phy(unmixed)
   
            m3_stat = {'mean': self.enc_dis3.func_m3_mean(feature_phy), 'lnvar': self.enc_dis3.func_m3_lnvar(feature_phy)}
            c3_stat = {'mean': self.enc_dis3.func_c3_mean(feature_phy), 'lnvar': self.enc_dis3.func_c3_lnvar(feature_phy)}
            k3_stat = {'mean': self.enc_dis3.func_k3_mean(feature_phy), 'lnvar': self.enc_dis3.func_k3_lnvar(feature_phy)}           
            init_x3_stat = {'mean': self.enc_dis3.func_init_x3_mean(feature_phy), 'lnvar': self.enc_dis3.func_init_x3_lnvar(feature_phy)}
            init_v3_stat = {'mean': self.enc_dis3.func_init_v3_mean(feature_phy), 'lnvar': self.enc_dis3.func_init_v3_lnvar(feature_phy)}

        else:
            unmixed = torch.zeros(n, self.dim_t)
         
            m3_stat = {'mean':torch.empty(n, 0, device= device), 'lnvar':torch.empty(n, 0, device= device)}
            c3_stat = {'mean':torch.empty(n, 0, device= device), 'lnvar':torch.empty(n, 0, device= device)}
            k3_stat = {'mean':torch.empty(n, 0, device= device), 'lnvar':torch.empty(n, 0, device= device)}
            init_x3_stat = {'mean':torch.empty(n, 0, device= device), 'lnvar':torch.empty(n, 0, device= device)}
            init_v3_stat = {'mean':torch.empty(n, 0, device= device), 'lnvar':torch.empty(n, 0, device= device)}


        return m3_stat,c3_stat,k3_stat,init_x3_stat,init_v3_stat,z_aux9_stat, z_aux10_stat, unmixed


    def draw(self, m3_stat:dict,c3_stat:dict,k3_stat:dict,init_x3_stat:dict,init_v3_stat:dict, z_aux9_stat:dict,z_aux10_stat:dict, hard_z:bool=False):
        if not hard_z:
            
            m3 = draw_normal(m3_stat['mean'], m3_stat['lnvar'])
            c3 = draw_normal(c3_stat['mean'], c3_stat['lnvar'])
            k3 = draw_normal(k3_stat['mean'], k3_stat['lnvar'])
            init_x3 = draw_normal(init_x3_stat['mean'], init_x3_stat['lnvar'])
            init_v3 = draw_normal(init_v3_stat['mean'], init_v3_stat['lnvar'])
            z_aux9 =draw_normal(z_aux9_stat['mean'], z_aux9_stat['lnvar'])
            z_aux10 =draw_normal(z_aux10_stat['mean'], z_aux10_stat['lnvar'])
        else:
      
            m3 = m3_stat['mean'].clone()
            c3 = c3_stat['mean'].clone()
            k3 = k3_stat['mean'].clone()
            init_x3 = init_x3_stat['mean'].clone()
            init_v3 = init_x3_stat['mean'].clone()
            z_aux9 = z_aux9_stat['mean'].clone()
            z_aux10 = z_aux10_stat['mean'].clone()


        return m3,c3,k3,init_x3,init_v3, z_aux9, z_aux10


    def forward(self, x:torch.Tensor, reconstruct:bool=True, hard_z:bool=False):
        m3_stat,c3_stat,k3_stat,init_x3_stat,init_v3_stat,z_aux9_stat, z_aux10_stat, unmixed = self.encode(x)

        if not reconstruct:
            return m3_stat,c3_stat,k3_stat,init_x3_stat,init_v3_stat,z_aux9_stat, z_aux10_stat, unmixed

        # draw & reconstruction
        m3,c3,k3,init_x3,init_v3, z_aux9, z_aux10 = self.draw(m3_stat,c3_stat,k3_stat,init_x3_stat,init_v3_stat,z_aux9_stat, z_aux10_stat, hard_z=hard_z)
        x_mean, x_lnvar = self.decode(m3,c3,k3,init_x3,init_v3, z_aux9, z_aux10, full=False)

        return m3_stat,c3_stat,k3_stat,init_x3_stat,init_v3_stat,z_aux9_stat, z_aux10_stat, x_mean, x_lnvar

# %% [markdown]
# # TF: Displacement 3

# %%
import numpy as np
import torch
from torch import optim


def loss_function_dis3(data,m3_stat,c3_stat,k3_stat,init_x3_stat,init_v3_stat, z_aux9_stat, z_aux10_stat, x_mean):
    n = data.shape[0]
    device= data.device
    

    recerr_sq = torch.sum((x_mean - data).pow(2), dim=1).mean()

    prior_m3_stat,prior_c3_stat,prior_k3_stat, prior_init_x3_stat,prior_init_v3_stat,prior_z_aux9_stat, prior_z_aux10_stat = model_dis3.priors(n, device)

    KL_z_aux9 = kldiv_normal_normal(z_aux9_stat['mean'], z_aux9_stat['lnvar'],
        prior_z_aux9_stat['mean'], prior_z_aux9_stat['lnvar']) if config_dis3['dim_z_aux9'] > 0 else torch.zeros(1, device= device)
    KL_z_aux10 = kldiv_normal_normal(z_aux10_stat['mean'], z_aux10_stat['lnvar'],
        prior_z_aux10_stat['mean'], prior_z_aux10_stat['lnvar']) if config_dis3['dim_z_aux10'] > 0 else torch.zeros(1, device= device)

    KL_m3 = kldiv_normal_normal(m3_stat['mean'], m3_stat['lnvar'],
        prior_m3_stat['mean'], prior_m3_stat['lnvar']) if not config_dis3['no_phy'] else torch.zeros(1, device= device)
    KL_c3 = kldiv_normal_normal(c3_stat['mean'], c3_stat['lnvar'],
        prior_c3_stat['mean'], prior_c3_stat['lnvar']) if not config_dis3['no_phy'] else torch.zeros(1, device= device)
    KL_k3 = kldiv_normal_normal(k3_stat['mean'], k3_stat['lnvar'],
        prior_k3_stat['mean'], prior_k3_stat['lnvar']) if not config_dis3['no_phy'] else torch.zeros(1, device= device)

    KL_init_x3 = kldiv_normal_normal(init_x3_stat['mean'], init_x3_stat['lnvar'],
        prior_init_x3_stat['mean'], prior_init_x3_stat['lnvar']) if not config_dis3['no_phy'] else torch.zeros(1, device= device)
    KL_init_v3 = kldiv_normal_normal(init_v3_stat['mean'], init_v3_stat['lnvar'],
        prior_init_x3_stat['mean'], prior_init_x3_stat['lnvar']) if not config_dis3['no_phy'] else torch.zeros(1, device= device)

    kldiv = (KL_z_aux9 +KL_z_aux10 +KL_m3 +KL_c3 +KL_k3  +KL_init_x3+KL_init_v3).mean()

    return recerr_sq, KL_z_aux9.mean() ,KL_z_aux10.mean(),KL_m3.mean(), KL_c3.mean(), KL_k3.mean(), KL_init_x3.mean(),KL_init_v3.mean(),kldiv

def train_dis3(epoch, device, loader, model, optimizer):

    model.train()
    logs = {'recerr_sq':.0, 'KL_z_aux9':.0, 'KL_z_aux10':.0, 'KL_m3':.0,'KL_c3':.0,'KL_k3':.0,'KL_c4':.0,'KL_k4':.0,'KL_init_x3':.0 ,'KL_init_v3':.0 }

    for batch_idx, (data,) in enumerate(loader):
        
        data= data.to(device)
        batch_size = len(data)
        optimizer.zero_grad()

        # inference & reconstruction on original data
        m3_stat,c3_stat,k3_stat,init_x3_stat,init_v3_stat,z_aux9_stat, z_aux10_stat, unmixed = model.encode(data)
        m3,c3,k3,init_x3,init_v3, z_aux9, z_aux10 = model.draw(m3_stat,c3_stat,k3_stat,init_x3_stat,init_v3_stat,z_aux9_stat, z_aux10_stat, hard_z=False)
        x_PAB, x_lnvar = model.decode(m3,c3,k3,init_x3,init_v3, z_aux9, z_aux10, full=False)
        x_var = torch.exp(x_lnvar)
        

        # ELBO
        recerr_sq,KL_z_aux9 ,KL_z_aux10,KL_m3,KL_c3, KL_k3,  KL_init_x3,KL_init_v3, kldiv = loss_function_dis3(data, m3_stat,c3_stat,k3_stat,
                                                                                                                    init_x3_stat,init_v3_stat, z_aux9_stat, z_aux10_stat, x_PAB)

    
        # loss function        
        loss = recerr_sq + kldiv 
        
        # update model parameters
        loss.backward()
        if config_dis3['grad_clip']>0.0:
            torch.nn.utils.clip_grad_value_(model.parameters(), config_dis3['grad_clip'])
        optimizer.step()

        # log
        logs['recerr_sq'] += recerr_sq.detach()*batch_size
        logs['KL_z_aux9'] += KL_z_aux9.detach()*batch_size
        logs['KL_z_aux10'] += KL_z_aux10.detach()*batch_size
        logs['KL_m3'] += KL_m3.detach()*batch_size
        logs['KL_c3'] += KL_c3.detach()*batch_size
        logs['KL_k3'] += KL_k3.detach()*batch_size
        logs['KL_init_x3'] += KL_init_x3.detach()*batch_size
        logs['KL_init_v3'] += KL_init_v3.detach()*batch_size

    for key in logs:

        logs[key] /= len(loader.dataset)
    print('====> Epoch: {}  Training (rec. err.)^2: {:.4f}  KL_z_aux9: {} KL_z_aux10: {} KL_m3: {}  KL_c3: {} KL_k3: {} KL_init_x3: {}  KL_init_v3: {} '.format(
        epoch,  logs['recerr_sq'], logs['KL_z_aux9'], logs['KL_z_aux10'], logs['KL_m3'], logs['KL_c3'], logs['KL_k3'], logs['KL_init_x3'], logs['KL_init_v3']))
    return logs


def valid_dis3(epoch,device, loader, model):
    model.eval()
    logs = logs = {'recerr_sq':.0, 'KL_z_aux9':.0, 'KL_z_aux10':.0, 'KL_c3':.0,'KL_k3':.0,'KL_c4':.0,'KL_k4':.0,'KL_gamma':.0,'KL_omega':.0,'KL_init_x3':.0 ,'KL_init_v3':.0 }
    with torch.no_grad():
        for i, (data,) in enumerate(loader):
            
            data = data.to(device)
            batch_size = len(data)
            m3_stat,c3_stat,k3_stat,init_x3_stat,init_v3_stat,z_aux9_stat, z_aux10_stat, x_mean, x_lnvar= model(data)
            recerr_sq, KL_z_aux9 ,KL_z_aux10,KL_m3,KL_c3, KL_k3, KL_init_x3,KL_init_v3,kldiv = loss_function_dis3(data, m3_stat,c3_stat,k3_stat,
                                                                                                                         init_x3_stat,init_v3_stat, z_aux9_stat, z_aux10_stat, x_mean)

            logs['recerr_sq'] += recerr_sq.detach()*batch_size
            logs['KL_z_aux9'] += KL_z_aux9.detach()*batch_size
            logs['KL_z_aux10'] += KL_z_aux10.detach()*batch_size
            logs['KL_c3'] += KL_c3.detach()*batch_size
            logs['KL_k3'] += KL_k3.detach()*batch_size
            logs['KL_init_x3'] += KL_init_x3.detach()*batch_size
            logs['KL_init_v3'] += KL_init_v3.detach()*batch_size
            
            
        for key in logs:

            logs[key] /= len(loader.dataset)
        print('====> Epoch: {}  Validation (rec. err.)^2: {:.4f}  KL_z_aux9: {} KL_z_aux10: {} KL_c3: {} KL_k3: {} KL_init_x3: {}  KL_init_v3: {} '.format(
            epoch,  logs['recerr_sq'], logs['KL_z_aux9'], logs['KL_z_aux10'], logs['KL_c3'], logs['KL_k3'], logs['KL_init_x3'], logs['KL_init_v3']))
        return logs

# %% [markdown]
# # Config: Displacement 3

# %%
# range_alpha = [100,0]
# range_gamma = [50,0]
# range_omega = [10,0]

# %%
import numpy as np
config_dis3={
    'dim_t':400, 
    # prior knowledge
    
    'range_m3':[m3_mean,m3_std],
    'range_c3':[c3_mean,c3_std],
    'range_k3':[k3_mean,k3_std],    
    'range_init_x3': [x3_mean,x3_std],
    'range_init_v3': [v3_mean,v3_std],
    'gamma': 50,
    'omega':10,
    'alpha':100,
    
    #model(general)
    'dim_z_aux9' : 1,
    'dim_z_aux10' : 1,

    'intg_lev' : 1,
    'dt':0.01,
    'no_phy' : False,
    'ode_solver' : 'euler',
    'activation' : actmodule('elu'),
    
    # model (decoder)
    'x_lnvar' : -9.0,
    'hidlayers_aux1_dec' :[150,150,150],
    'hidlayers_aux2_dec' :[150,150,150],
    # model (encoder)
    'hidlayers_aux1_enc' : [150,150,150],
    'hidlayers_aux2_enc' : [150,150,150],
    'hidlayers_unmixer' : [150,150,150],

    'hidlayers_m3' : [150,150,150],
    'hidlayers_c3' : [150,150,150],
    'hidlayers_k3' : [150,150,150],
    'hidlayers_init_x3': [150,150,150],
    'hidlayers_init_v3': [150,150,150],

    'arch_feat' : 'mlp',
    'num_units_feat' : 264,
    'hidlayers_feat' : [164,164],
    'num_rnns_feat' : 1,


    # optimization (base)
    'learning_rate' : 1e-4,
    'weight_decay' : 1e-3,
    'adam_eps' : 1e-3,
    'grad_clip' : 5,
    'batch_size' : 250,
    'epochs' : 4000,

    # others
    'train_size' : 500,
    'save_interval' : 999999,
    'num_workers' : 0,
    'cuda': True,
    'seed' : 3407


}

# %% [markdown]
# # Train model: Displacement 3

# %%
# set random seed
torch.manual_seed(config_dis3['seed'])
dim_t = config_dis3['dim_t']
dt = config_dis3['dt']

if  config_dis3['train_size'] > 0:
    if  config_dis3['train_size'] > data_train_dis3.shape[0]:
        raise ValueError('train_size must be <= {}'.format(data_train_dis3.shape[0]))
    idx = torch.randperm(data_train_dis3.shape[0]).numpy()[0: config_dis3['train_size']]
    data_train_dis3 = data_train_dis3[idx]


# set data loaders
kwargs = {'num_workers': config_dis3['num_workers'], 'pin_memory': True} if config_dis3['cuda'] else {}
loader_train_dis3 = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(torch.Tensor(data_train_dis3).float()),
    batch_size= config_dis3['batch_size'], shuffle=True, **kwargs)
loader_valid_dis3 = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(torch.Tensor(data_valid_dis3).float()),
    batch_size=config_dis3['batch_size'], shuffle=False, **kwargs)


# set model
model_dis3 = VAE_dis3(config_dis3).to(device)


# set optimizer
kwargs = {'lr': config_dis3['learning_rate'], 'weight_decay': config_dis3['weight_decay'], 'eps': config_dis3['adam_eps']}
optimizer_dis3 = optim.Adam(model_dis3.parameters(), **kwargs)



print(vars())
print()



# main iteration
info = {'bestvalid_epoch':0, 'bestvalid_recerr':1}
dur_total = .0


kldiv_train_vel=[]
kldiv_valid_vel=[]
recerr_sq_loss_train_vel=[]
recerr_sq_loss_valid_vel=[]
total_loss_vel=[]
kldiv_balanced_loss_vel=[]

for epoch in range(1, config_dis3['epochs'] + 1):
    

    logs_train_dis3 = train_dis3(epoch, device, loader_train_dis3, model=model_dis3, optimizer=optimizer_dis3) 

    # validation
    logs_valid_dis3 = valid_dis3(epoch,device, loader_valid_dis3, model_dis3)
    
    # kldiv_train_vel.append(logs_train_dis3['kldiv_train'])
    # kldiv_valid_vel.append(logs_valid_dis3['kldiv_valid'])
    # recerr_sq_loss_train_vel.append(logs_train_dis3['recerr_sq'])
    # recerr_sq_loss_valid_vel.append(logs_valid_dis3['recerr_sq'])
    # total_loss_vel.append(logs_train_dis3['total_loss'])
  

print()
print('end training')

##saving model
torch.save(model_dis3.state_dict(),'best model_dis3.pt')
print('best model saved')
# Out:
# Streaming output truncated to the last 5000 lines.
# ====> Epoch: 1502  Validation (rec. err.)^2: 20.4077  KL_z_aux9: 3.126889705657959 KL_z_aux10: 0.1866087168455124 KL_c3: 0.03418063372373581 KL_k3: 1.5304867029190063 KL_init_x3: 0.03675977513194084  KL_init_v3: 0.03520979359745979
# ====> Epoch: 1503  Training (rec. err.)^2: 44.3950  KL_z_aux9: 3.0094668865203857 KL_z_aux10: 0.16516052186489105 KL_m3: 0.5480610132217407  KL_c3: 0.09550049155950546 KL_k3: 1.3785580396652222 KL_init_x3: 0.09831219911575317  KL_init_v3: 0.09651671350002289
# ====> Epoch: 1503  Validation (rec. err.)^2: 20.1490  KL_z_aux9: 3.1546826362609863 KL_z_aux10: 0.18636596202850342 KL_c3: 0.033923014998435974 KL_k3: 1.5296870470046997 KL_init_x3: 0.03670074790716171  KL_init_v3: 0.034909188747406006
# ====> Epoch: 1504  Training (rec. err.)^2: 49.5268  KL_z_aux9: 3.017543077468872 KL_z_aux10: 0.1637113392353058 KL_m3: 0.5116509199142456  KL_c3: 0.10155964642763138 KL_k3: 1.366451621055603 KL_init_x3: 0.09630119800567627  KL_init_v3: 0.10604787617921829
# ====> Epoch: 1504  Validation (rec. err.)^2: 20.1156  KL_z_aux9: 3.159926414489746 KL_z_aux10: 0.18634332716464996 KL_c3: 0.03371307998895645 KL_k3: 1.52707040309906 KL_init_x3: 0.036275338381528854  KL_init_v3: 0.03435899689793587
# ====> Epoch: 1505  Training (rec. err.)^2: 44.9831  KL_z_aux9: 3.015838623046875 KL_z_aux10: 0.16827484965324402 KL_m3: 0.527926504611969  KL_c3: 0.09806110709905624 KL_k3: 1.3983452320098877 KL_init_x3: 0.105056032538414  KL_init_v3: 0.10450591146945953
# ====> Epoch: 1505  Validation (rec. err.)^2: 20.6645  KL_z_aux9: 3.1538429260253906 KL_z_aux10: 0.1862134486436844 KL_c3: 0.03366030380129814 KL_k3: 1.5249085426330566 KL_init_x3: 0.035939935594797134  KL_init_v3: 0.0338628925383091
# ====> Epoch: 1506  Training (rec. err.)^2: 45.5848  KL_z_aux9: 3.037792205810547 KL_z_aux10: 0.17132018506526947 KL_m3: 0.5405327677726746  KL_c3: 0.10030212998390198 KL_k3: 1.343570590019226 KL_init_x3: 0.09703420847654343  KL_init_v3: 0.09518273174762726
# ====> Epoch: 1506  Validation (rec. err.)^2: 20.5617  KL_z_aux9: 3.1833317279815674 KL_z_aux10: 0.18664351105690002 KL_c3: 0.03404386341571808 KL_k3: 1.5252623558044434 KL_init_x3: 0.03606453910470009  KL_init_v3: 0.033667825162410736
# ====> Epoch: 1507  Training (rec. err.)^2: 44.9172  KL_z_aux9: 3.1115217208862305 KL_z_aux10: 0.16619087755680084 KL_m3: 0.5302578806877136  KL_c3: 0.08580262213945389 KL_k3: 1.3616679906845093 KL_init_x3: 0.10777740925550461  KL_init_v3: 0.09164433181285858
# ====> Epoch: 1507  Validation (rec. err.)^2: 20.3430  KL_z_aux9: 3.183316946029663 KL_z_aux10: 0.18714062869548798 KL_c3: 0.03482665494084358 KL_k3: 1.5290193557739258 KL_init_x3: 0.03657512739300728  KL_init_v3: 0.03372007980942726
# ====> Epoch: 1508  Training (rec. err.)^2: 44.0596  KL_z_aux9: 3.0206263065338135 KL_z_aux10: 0.16861334443092346 KL_m3: 0.5474429130554199  KL_c3: 0.08456538617610931 KL_k3: 1.3653525114059448 KL_init_x3: 0.10422660410404205  KL_init_v3: 0.10320127010345459
# ====> Epoch: 1508  Validation (rec. err.)^2: 20.3853  KL_z_aux9: 3.160797595977783 KL_z_aux10: 0.18813978135585785 KL_c3: 0.035102929919958115 KL_k3: 1.5315306186676025 KL_init_x3: 0.036810051649808884  KL_init_v3: 0.03361815586686134
# ====> Epoch: 1509  Training (rec. err.)^2: 45.4386  KL_z_aux9: 3.0268449783325195 KL_z_aux10: 0.17412930727005005 KL_m3: 0.5306439399719238  KL_c3: 0.09855789691209793 KL_k3: 1.3679649829864502 KL_init_x3: 0.10374623537063599  KL_init_v3: 0.09873981773853302
# ====> Epoch: 1509  Validation (rec. err.)^2: 20.3468  KL_z_aux9: 3.154801368713379 KL_z_aux10: 0.18909408152103424 KL_c3: 0.034994013607501984 KL_k3: 1.5329447984695435 KL_init_x3: 0.0368286669254303  KL_init_v3: 0.03345414996147156
# ====> Epoch: 1510  Training (rec. err.)^2: 46.3127  KL_z_aux9: 3.052891254425049 KL_z_aux10: 0.16946916282176971 KL_m3: 0.5460481643676758  KL_c3: 0.09724478423595428 KL_k3: 1.398364543914795 KL_init_x3: 0.11091127246618271  KL_init_v3: 0.10172379016876221
# ====> Epoch: 1510  Validation (rec. err.)^2: 20.0824  KL_z_aux9: 3.1485342979431152 KL_z_aux10: 0.19043518602848053 KL_c3: 0.034628190100193024 KL_k3: 1.5339915752410889 KL_init_x3: 0.03668432682752609  KL_init_v3: 0.03309781476855278
# ====> Epoch: 1511  Training (rec. err.)^2: 48.3719  KL_z_aux9: 3.011697292327881 KL_z_aux10: 0.17386212944984436 KL_m3: 0.5265542268753052  KL_c3: 0.09264719486236572 KL_k3: 1.3726553916931152 KL_init_x3: 0.10171546041965485  KL_init_v3: 0.09647433459758759
# ====> Epoch: 1511  Validation (rec. err.)^2: 20.6089  KL_z_aux9: 3.1344146728515625 KL_z_aux10: 0.1915726363658905 KL_c3: 0.03428424522280693 KL_k3: 1.5352436304092407 KL_init_x3: 0.03646194934844971  KL_init_v3: 0.032576169818639755
# ====> Epoch: 1512  Training (rec. err.)^2: 46.2280  KL_z_aux9: 3.014894723892212 KL_z_aux10: 0.17758740484714508 KL_m3: 0.5360389947891235  KL_c3: 0.09637390077114105 KL_k3: 1.417288064956665 KL_init_x3: 0.1019577831029892  KL_init_v3: 0.10412218421697617
# ====> Epoch: 1512  Validation (rec. err.)^2: 20.1990  KL_z_aux9: 3.127422571182251 KL_z_aux10: 0.19264860451221466 KL_c3: 0.034057702869176865 KL_k3: 1.5307530164718628 KL_init_x3: 0.035958629101514816  KL_init_v3: 0.031867098063230515
# ====> Epoch: 1513  Training (rec. err.)^2: 45.7866  KL_z_aux9: 3.018960475921631 KL_z_aux10: 0.17107407748699188 KL_m3: 0.516304612159729  KL_c3: 0.09620524197816849 KL_k3: 1.3499517440795898 KL_init_x3: 0.09688302874565125  KL_init_v3: 0.0941452607512474
# ====> Epoch: 1513  Validation (rec. err.)^2: 20.4249  KL_z_aux9: 3.1560182571411133 KL_z_aux10: 0.1939307302236557 KL_c3: 0.03452686592936516 KL_k3: 1.5285271406173706 KL_init_x3: 0.03583560883998871  KL_init_v3: 0.03199368715286255
# ====> Epoch: 1514  Training (rec. err.)^2: 46.2882  KL_z_aux9: 3.016655445098877 KL_z_aux10: 0.17304572463035583 KL_m3: 0.5291229486465454  KL_c3: 0.09344004094600677 KL_k3: 1.3881467580795288 KL_init_x3: 0.09966319054365158  KL_init_v3: 0.09844571352005005
# ====> Epoch: 1514  Validation (rec. err.)^2: 20.2153  KL_z_aux9: 3.1306543350219727 KL_z_aux10: 0.19475647807121277 KL_c3: 0.035522378981113434 KL_k3: 1.529184341430664 KL_init_x3: 0.036025259643793106  KL_init_v3: 0.03270835429430008
# ====> Epoch: 1515  Training (rec. err.)^2: 45.9065  KL_z_aux9: 3.01796555519104 KL_z_aux10: 0.17745597660541534 KL_m3: 0.5248721837997437  KL_c3: 0.10583086311817169 KL_k3: 1.3784663677215576 KL_init_x3: 0.10552356392145157  KL_init_v3: 0.09453819692134857
# ====> Epoch: 1515  Validation (rec. err.)^2: 20.3499  KL_z_aux9: 3.104027032852173 KL_z_aux10: 0.19530914723873138 KL_c3: 0.036727141588926315 KL_k3: 1.5298585891723633 KL_init_x3: 0.036294642835855484  KL_init_v3: 0.03340901434421539
# ====> Epoch: 1516  Training (rec. err.)^2: 47.6665  KL_z_aux9: 2.9761159420013428 KL_z_aux10: 0.17763984203338623 KL_m3: 0.5361331105232239  KL_c3: 0.09356033056974411 KL_k3: 1.372613787651062 KL_init_x3: 0.1028299331665039  KL_init_v3: 0.10267553478479385
# ====> Epoch: 1516  Validation (rec. err.)^2: 20.7177  KL_z_aux9: 3.114314079284668 KL_z_aux10: 0.19644087553024292 KL_c3: 0.037803057581186295 KL_k3: 1.5292590856552124 KL_init_x3: 0.03666269779205322  KL_init_v3: 0.033984504640102386
# ====> Epoch: 1517  Training (rec. err.)^2: 44.9498  KL_z_aux9: 3.0075860023498535 KL_z_aux10: 0.1792970448732376 KL_m3: 0.5772687792778015  KL_c3: 0.10215984284877777 KL_k3: 1.3917186260223389 KL_init_x3: 0.09366153180599213  KL_init_v3: 0.1010817438364029
# ====> Epoch: 1517  Validation (rec. err.)^2: 20.5215  KL_z_aux9: 3.1587774753570557 KL_z_aux10: 0.1974247843027115 KL_c3: 0.038768306374549866 KL_k3: 1.5272899866104126 KL_init_x3: 0.03707772120833397  KL_init_v3: 0.034355200827121735
# ====> Epoch: 1518  Training (rec. err.)^2: 43.7236  KL_z_aux9: 3.0564606189727783 KL_z_aux10: 0.17805133759975433 KL_m3: 0.5516399145126343  KL_c3: 0.10078820586204529 KL_k3: 1.3606410026550293 KL_init_x3: 0.09513486921787262  KL_init_v3: 0.10013570636510849
# ====> Epoch: 1518  Validation (rec. err.)^2: 20.2958  KL_z_aux9: 3.150017499923706 KL_z_aux10: 0.19841368496418 KL_c3: 0.0385967493057251 KL_k3: 1.5211485624313354 KL_init_x3: 0.036339059472084045  KL_init_v3: 0.03384048119187355
# ====> Epoch: 1519  Training (rec. err.)^2: 44.5725  KL_z_aux9: 3.0112390518188477 KL_z_aux10: 0.17986619472503662 KL_m3: 0.549209475517273  KL_c3: 0.08888185769319534 KL_k3: 1.3783365488052368 KL_init_x3: 0.10174848139286041  KL_init_v3: 0.10685450583696365
# ====> Epoch: 1519  Validation (rec. err.)^2: 20.2549  KL_z_aux9: 3.0911788940429688 KL_z_aux10: 0.1994561403989792 KL_c3: 0.037560854107141495 KL_k3: 1.5122274160385132 KL_init_x3: 0.034786514937877655  KL_init_v3: 0.03264757618308067
# ====> Epoch: 1520  Training (rec. err.)^2: 46.1279  KL_z_aux9: 2.955944776535034 KL_z_aux10: 0.19197513163089752 KL_m3: 0.5373541712760925  KL_c3: 0.0891900360584259 KL_k3: 1.378975749015808 KL_init_x3: 0.10270261019468307  KL_init_v3: 0.09246480464935303
# ====> Epoch: 1520  Validation (rec. err.)^2: 20.4804  KL_z_aux9: 3.1019794940948486 KL_z_aux10: 0.19989687204360962 KL_c3: 0.03702305629849434 KL_k3: 1.50492262840271 KL_init_x3: 0.033824168145656586  KL_init_v3: 0.03208131715655327
# ====> Epoch: 1521  Training (rec. err.)^2: 45.7367  KL_z_aux9: 2.967951536178589 KL_z_aux10: 0.18120363354682922 KL_m3: 0.5364670753479004  KL_c3: 0.1030244305729866 KL_k3: 1.3353807926177979 KL_init_x3: 0.09596952795982361  KL_init_v3: 0.09941263496875763
# ====> Epoch: 1521  Validation (rec. err.)^2: 20.2700  KL_z_aux9: 3.1411428451538086 KL_z_aux10: 0.19989772140979767 KL_c3: 0.03778962045907974 KL_k3: 1.5023870468139648 KL_init_x3: 0.03387860581278801  KL_init_v3: 0.03238728269934654
# ====> Epoch: 1522  Training (rec. err.)^2: 47.6728  KL_z_aux9: 3.0019419193267822 KL_z_aux10: 0.18907655775547028 KL_m3: 0.5155395269393921  KL_c3: 0.09400604665279388 KL_k3: 1.3211270570755005 KL_init_x3: 0.10336673259735107  KL_init_v3: 0.08802112191915512
# ====> Epoch: 1522  Validation (rec. err.)^2: 20.6128  KL_z_aux9: 3.1393778324127197 KL_z_aux10: 0.1998930126428604 KL_c3: 0.0390712209045887 KL_k3: 1.5006394386291504 KL_init_x3: 0.0340501144528389  KL_init_v3: 0.03279273211956024
# ====> Epoch: 1523  Training (rec. err.)^2: 48.2973  KL_z_aux9: 3.0086658000946045 KL_z_aux10: 0.18833127617835999 KL_m3: 0.5867457985877991  KL_c3: 0.09190721809864044 KL_k3: 1.3581637144088745 KL_init_x3: 0.1025221198797226  KL_init_v3: 0.09265165030956268
# ====> Epoch: 1523  Validation (rec. err.)^2: 20.4666  KL_z_aux9: 3.105057954788208 KL_z_aux10: 0.1996154636144638 KL_c3: 0.04048130288720131 KL_k3: 1.4997698068618774 KL_init_x3: 0.034204378724098206  KL_init_v3: 0.03327314928174019
# ====> Epoch: 1524  Training (rec. err.)^2: 44.3830  KL_z_aux9: 2.954760789871216 KL_z_aux10: 0.17607825994491577 KL_m3: 0.5621053576469421  KL_c3: 0.10372160375118256 KL_k3: 1.3305720090866089 KL_init_x3: 0.10916952788829803  KL_init_v3: 0.09960060566663742
# ====> Epoch: 1524  Validation (rec. err.)^2: 20.3348  KL_z_aux9: 3.129743814468384 KL_z_aux10: 0.19869789481163025 KL_c3: 0.04175940155982971 KL_k3: 1.4974582195281982 KL_init_x3: 0.034271981567144394  KL_init_v3: 0.03381970152258873
# ====> Epoch: 1525  Training (rec. err.)^2: 45.7712  KL_z_aux9: 2.978377342224121 KL_z_aux10: 0.17990832030773163 KL_m3: 0.55500727891922  KL_c3: 0.09968071430921555 KL_k3: 1.3493311405181885 KL_init_x3: 0.09898260980844498  KL_init_v3: 0.10139936953783035
# ====> Epoch: 1525  Validation (rec. err.)^2: 20.2654  KL_z_aux9: 3.149394989013672 KL_z_aux10: 0.19766086339950562 KL_c3: 0.04193434864282608 KL_k3: 1.4921387434005737 KL_init_x3: 0.0339917428791523  KL_init_v3: 0.03382240980863571
# ====> Epoch: 1526  Training (rec. err.)^2: 45.7290  KL_z_aux9: 3.023336172103882 KL_z_aux10: 0.17830753326416016 KL_m3: 0.5543666481971741  KL_c3: 0.09839197248220444 KL_k3: 1.3273944854736328 KL_init_x3: 0.09823467582464218  KL_init_v3: 0.10573221743106842
# ====> Epoch: 1526  Validation (rec. err.)^2: 20.2458  KL_z_aux9: 3.1468842029571533 KL_z_aux10: 0.19631634652614594 KL_c3: 0.04023345559835434 KL_k3: 1.4842652082443237 KL_init_x3: 0.033013612031936646  KL_init_v3: 0.03262010216712952
# ====> Epoch: 1527  Training (rec. err.)^2: 44.7604  KL_z_aux9: 2.9912214279174805 KL_z_aux10: 0.17823895812034607 KL_m3: 0.526605486869812  KL_c3: 0.09619744122028351 KL_k3: 1.3010032176971436 KL_init_x3: 0.09446179121732712  KL_init_v3: 0.10049597173929214
# ====> Epoch: 1527  Validation (rec. err.)^2: 20.6613  KL_z_aux9: 3.1381490230560303 KL_z_aux10: 0.19521179795265198 KL_c3: 0.038074858486652374 KL_k3: 1.4780986309051514 KL_init_x3: 0.03167411684989929  KL_init_v3: 0.031014902517199516
# ====> Epoch: 1528  Training (rec. err.)^2: 46.7850  KL_z_aux9: 3.052541732788086 KL_z_aux10: 0.17775867879390717 KL_m3: 0.530987560749054  KL_c3: 0.09562564641237259 KL_k3: 1.345410704612732 KL_init_x3: 0.09773945063352585  KL_init_v3: 0.10188927501440048
# ====> Epoch: 1528  Validation (rec. err.)^2: 20.2174  KL_z_aux9: 3.1681249141693115 KL_z_aux10: 0.19470685720443726 KL_c3: 0.037021905183792114 KL_k3: 1.4771795272827148 KL_init_x3: 0.031076906248927116  KL_init_v3: 0.030245481058955193
# ====> Epoch: 1529  Training (rec. err.)^2: 45.2818  KL_z_aux9: 3.110192060470581 KL_z_aux10: 0.18181729316711426 KL_m3: 0.5007618069648743  KL_c3: 0.09103227406740189 KL_k3: 1.302123785018921 KL_init_x3: 0.10758426785469055  KL_init_v3: 0.09430254250764847
# ====> Epoch: 1529  Validation (rec. err.)^2: 20.2097  KL_z_aux9: 3.1469478607177734 KL_z_aux10: 0.19400696456432343 KL_c3: 0.036393970251083374 KL_k3: 1.4802945852279663 KL_init_x3: 0.030780350789427757  KL_init_v3: 0.029891053214669228
# ====> Epoch: 1530  Training (rec. err.)^2: 47.2715  KL_z_aux9: 2.9857640266418457 KL_z_aux10: 0.17406344413757324 KL_m3: 0.5198728442192078  KL_c3: 0.10254895687103271 KL_k3: 1.352044701576233 KL_init_x3: 0.10133582353591919  KL_init_v3: 0.09548299759626389
# ====> Epoch: 1530  Validation (rec. err.)^2: 20.4629  KL_z_aux9: 3.107254981994629 KL_z_aux10: 0.19367080926895142 KL_c3: 0.03633430600166321 KL_k3: 1.4881982803344727 KL_init_x3: 0.03107955865561962  KL_init_v3: 0.030130617320537567
# ====> Epoch: 1531  Training (rec. err.)^2: 46.3218  KL_z_aux9: 2.996206760406494 KL_z_aux10: 0.17464914917945862 KL_m3: 0.5107445120811462  KL_c3: 0.1019749790430069 KL_k3: 1.3346503973007202 KL_init_x3: 0.10260573029518127  KL_init_v3: 0.0986153781414032
# ====> Epoch: 1531  Validation (rec. err.)^2: 19.9525  KL_z_aux9: 3.131612539291382 KL_z_aux10: 0.1939319521188736 KL_c3: 0.03750791773200035 KL_k3: 1.499522089958191 KL_init_x3: 0.03228827193379402  KL_init_v3: 0.03147366642951965
# ====> Epoch: 1532  Training (rec. err.)^2: 45.7172  KL_z_aux9: 3.0522735118865967 KL_z_aux10: 0.17826242744922638 KL_m3: 0.5506404042243958  KL_c3: 0.08839012682437897 KL_k3: 1.3609100580215454 KL_init_x3: 0.1030106469988823  KL_init_v3: 0.09374843537807465
# ====> Epoch: 1532  Validation (rec. err.)^2: 20.1901  KL_z_aux9: 3.130190134048462 KL_z_aux10: 0.19515524804592133 KL_c3: 0.038480546325445175 KL_k3: 1.5089555978775024 KL_init_x3: 0.0332782156765461  KL_init_v3: 0.03272804245352745
# ====> Epoch: 1533  Training (rec. err.)^2: 45.5226  KL_z_aux9: 3.0572075843811035 KL_z_aux10: 0.17530083656311035 KL_m3: 0.5417771339416504  KL_c3: 0.08781415969133377 KL_k3: 1.3559290170669556 KL_init_x3: 0.09911226481199265  KL_init_v3: 0.09288809448480606
# ====> Epoch: 1533  Validation (rec. err.)^2: 20.5537  KL_z_aux9: 3.0697383880615234 KL_z_aux10: 0.1960981786251068 KL_c3: 0.03841444477438927 KL_k3: 1.515863060951233 KL_init_x3: 0.033712342381477356  KL_init_v3: 0.03315628692507744
# ====> Epoch: 1534  Training (rec. err.)^2: 45.6344  KL_z_aux9: 2.962460994720459 KL_z_aux10: 0.17808900773525238 KL_m3: 0.5257706642150879  KL_c3: 0.09391488879919052 KL_k3: 1.32667076587677 KL_init_x3: 0.09862076491117477  KL_init_v3: 0.09967538714408875
# ====> Epoch: 1534  Validation (rec. err.)^2: 20.6303  KL_z_aux9: 3.056975841522217 KL_z_aux10: 0.19669528305530548 KL_c3: 0.0386619009077549 KL_k3: 1.5231558084487915 KL_init_x3: 0.03423221409320831  KL_init_v3: 0.03368627279996872
# ====> Epoch: 1535  Training (rec. err.)^2: 45.8718  KL_z_aux9: 2.9454448223114014 KL_z_aux10: 0.1765621304512024 KL_m3: 0.5166817903518677  KL_c3: 0.10098142176866531 KL_k3: 1.364180326461792 KL_init_x3: 0.11013445258140564  KL_init_v3: 0.09346853941679001
# ====> Epoch: 1535  Validation (rec. err.)^2: 20.2572  KL_z_aux9: 3.1291167736053467 KL_z_aux10: 0.1967492401599884 KL_c3: 0.0393790602684021 KL_k3: 1.530890941619873 KL_init_x3: 0.0351957343518734  KL_init_v3: 0.034530725330114365
# ====> Epoch: 1536  Training (rec. err.)^2: 46.9149  KL_z_aux9: 3.014460325241089 KL_z_aux10: 0.17801982164382935 KL_m3: 0.5308048129081726  KL_c3: 0.09619870781898499 KL_k3: 1.3731399774551392 KL_init_x3: 0.08702556043863297  KL_init_v3: 0.0911145806312561
# ====> Epoch: 1536  Validation (rec. err.)^2: 20.5493  KL_z_aux9: 3.1539504528045654 KL_z_aux10: 0.1964891105890274 KL_c3: 0.03963359072804451 KL_k3: 1.5368376970291138 KL_init_x3: 0.035884127020835876  KL_init_v3: 0.03489522635936737
# ====> Epoch: 1537  Training (rec. err.)^2: 45.3073  KL_z_aux9: 3.01070237159729 KL_z_aux10: 0.1806821972131729 KL_m3: 0.5391018390655518  KL_c3: 0.08862701803445816 KL_k3: 1.4162042140960693 KL_init_x3: 0.1023368239402771  KL_init_v3: 0.09973026812076569
# ====> Epoch: 1537  Validation (rec. err.)^2: 19.9150  KL_z_aux9: 3.069037675857544 KL_z_aux10: 0.19560015201568604 KL_c3: 0.03854469582438469 KL_k3: 1.539238691329956 KL_init_x3: 0.03546843305230141  KL_init_v3: 0.03416169807314873
# ====> Epoch: 1538  Training (rec. err.)^2: 43.6519  KL_z_aux9: 2.933391809463501 KL_z_aux10: 0.17618650197982788 KL_m3: 0.5602986216545105  KL_c3: 0.09596521407365799 KL_k3: 1.363786220550537 KL_init_x3: 0.09057623893022537  KL_init_v3: 0.10665435343980789
# ====> Epoch: 1538  Validation (rec. err.)^2: 20.5105  KL_z_aux9: 3.0445303916931152 KL_z_aux10: 0.19519218802452087 KL_c3: 0.03776507079601288 KL_k3: 1.5425176620483398 KL_init_x3: 0.03510015457868576  KL_init_v3: 0.033600885421037674
# ====> Epoch: 1539  Training (rec. err.)^2: 44.7285  KL_z_aux9: 2.95141863822937 KL_z_aux10: 0.17985856533050537 KL_m3: 0.5388198494911194  KL_c3: 0.09668609499931335 KL_k3: 1.3884197473526 KL_init_x3: 0.09757935255765915  KL_init_v3: 0.10031735897064209
# ====> Epoch: 1539  Validation (rec. err.)^2: 20.1541  KL_z_aux9: 3.1028244495391846 KL_z_aux10: 0.1953183114528656 KL_c3: 0.037210382521152496 KL_k3: 1.544648289680481 KL_init_x3: 0.03484351187944412  KL_init_v3: 0.033383697271347046
# ====> Epoch: 1540  Training (rec. err.)^2: 45.7335  KL_z_aux9: 3.0032143592834473 KL_z_aux10: 0.17494602501392365 KL_m3: 0.5476385354995728  KL_c3: 0.09347465634346008 KL_k3: 1.380021572113037 KL_init_x3: 0.0952814519405365  KL_init_v3: 0.09618517011404037
# ====> Epoch: 1540  Validation (rec. err.)^2: 20.1359  KL_z_aux9: 3.0928266048431396 KL_z_aux10: 0.19501128792762756 KL_c3: 0.0367840975522995 KL_k3: 1.54439115524292 KL_init_x3: 0.03439461812376976  KL_init_v3: 0.03314577788114548
# ====> Epoch: 1541  Training (rec. err.)^2: 45.8999  KL_z_aux9: 2.9752774238586426 KL_z_aux10: 0.17777428030967712 KL_m3: 0.5443373322486877  KL_c3: 0.10263768583536148 KL_k3: 1.3933062553405762 KL_init_x3: 0.10818997770547867  KL_init_v3: 0.10473162680864334
# ====> Epoch: 1541  Validation (rec. err.)^2: 20.1904  KL_z_aux9: 3.00288724899292 KL_z_aux10: 0.19452916085720062 KL_c3: 0.03661033511161804 KL_k3: 1.5432183742523193 KL_init_x3: 0.034057822078466415  KL_init_v3: 0.03308473527431488
# ====> Epoch: 1542  Training (rec. err.)^2: 44.7843  KL_z_aux9: 2.8721628189086914 KL_z_aux10: 0.1726195216178894 KL_m3: 0.5205570459365845  KL_c3: 0.10198421031236649 KL_k3: 1.3866592645645142 KL_init_x3: 0.0956190973520279  KL_init_v3: 0.09049451351165771
# ====> Epoch: 1542  Validation (rec. err.)^2: 20.5874  KL_z_aux9: 2.991184711456299 KL_z_aux10: 0.1942480504512787 KL_c3: 0.03646333888173103 KL_k3: 1.5426409244537354 KL_init_x3: 0.033939383924007416  KL_init_v3: 0.03337186202406883
# ====> Epoch: 1543  Training (rec. err.)^2: 44.7223  KL_z_aux9: 2.9004058837890625 KL_z_aux10: 0.17598581314086914 KL_m3: 0.5453331470489502  KL_c3: 0.09756531566381454 KL_k3: 1.3768587112426758 KL_init_x3: 0.09646231681108475  KL_init_v3: 0.10413698107004166
# ====> Epoch: 1543  Validation (rec. err.)^2: 20.1286  KL_z_aux9: 3.056413173675537 KL_z_aux10: 0.19416549801826477 KL_c3: 0.03706406429409981 KL_k3: 1.5453052520751953 KL_init_x3: 0.03445591405034065  KL_init_v3: 0.03434174880385399
# ====> Epoch: 1544  Training (rec. err.)^2: 45.5769  KL_z_aux9: 2.932396173477173 KL_z_aux10: 0.1795838475227356 KL_m3: 0.5866280794143677  KL_c3: 0.0988377183675766 KL_k3: 1.3724308013916016 KL_init_x3: 0.09883803129196167  KL_init_v3: 0.0903405249118805
# ====> Epoch: 1544  Validation (rec. err.)^2: 20.1723  KL_z_aux9: 3.05173397064209 KL_z_aux10: 0.1937810182571411 KL_c3: 0.03633098676800728 KL_k3: 1.5434175729751587 KL_init_x3: 0.03397758677601814  KL_init_v3: 0.03410736843943596
# ====> Epoch: 1545  Training (rec. err.)^2: 45.6246  KL_z_aux9: 2.978052854537964 KL_z_aux10: 0.17378175258636475 KL_m3: 0.5584582686424255  KL_c3: 0.09200562536716461 KL_k3: 1.3608150482177734 KL_init_x3: 0.10242512822151184  KL_init_v3: 0.10912171006202698
# ====> Epoch: 1545  Validation (rec. err.)^2: 20.6415  KL_z_aux9: 3.007169008255005 KL_z_aux10: 0.19307290017604828 KL_c3: 0.035456229001283646 KL_k3: 1.541490077972412 KL_init_x3: 0.03356952965259552  KL_init_v3: 0.03380561247467995
# ====> Epoch: 1546  Training (rec. err.)^2: 46.0768  KL_z_aux9: 2.8709664344787598 KL_z_aux10: 0.17535634338855743 KL_m3: 0.5532035231590271  KL_c3: 0.09801927953958511 KL_k3: 1.360933780670166 KL_init_x3: 0.10816077142953873  KL_init_v3: 0.10887166112661362
# ====> Epoch: 1546  Validation (rec. err.)^2: 20.4336  KL_z_aux9: 3.0385313034057617 KL_z_aux10: 0.19301988184452057 KL_c3: 0.03506075590848923 KL_k3: 1.5436921119689941 KL_init_x3: 0.03378954529762268  KL_init_v3: 0.034038245677948
# ====> Epoch: 1547  Training (rec. err.)^2: 44.5955  KL_z_aux9: 2.926560640335083 KL_z_aux10: 0.1746494174003601 KL_m3: 0.5443416833877563  KL_c3: 0.09545847028493881 KL_k3: 1.395221471786499 KL_init_x3: 0.0954381600022316  KL_init_v3: 0.0985429435968399
# ====> Epoch: 1547  Validation (rec. err.)^2: 20.1252  KL_z_aux9: 3.080059766769409 KL_z_aux10: 0.1925070881843567 KL_c3: 0.03515758737921715 KL_k3: 1.5482794046401978 KL_init_x3: 0.03438376635313034  KL_init_v3: 0.034716952592134476
# ====> Epoch: 1548  Training (rec. err.)^2: 44.2269  KL_z_aux9: 2.918212652206421 KL_z_aux10: 0.17579585313796997 KL_m3: 0.5542738437652588  KL_c3: 0.09812982380390167 KL_k3: 1.4204438924789429 KL_init_x3: 0.09768941253423691  KL_init_v3: 0.0977298766374588
# ====> Epoch: 1548  Validation (rec. err.)^2: 20.1112  KL_z_aux9: 3.0658233165740967 KL_z_aux10: 0.1924166977405548 KL_c3: 0.03554878383874893 KL_k3: 1.552196741104126 KL_init_x3: 0.03486885130405426  KL_init_v3: 0.03561820462346077
# ====> Epoch: 1549  Training (rec. err.)^2: 45.1564  KL_z_aux9: 2.924510955810547 KL_z_aux10: 0.17340052127838135 KL_m3: 0.5741313695907593  KL_c3: 0.09889078885316849 KL_k3: 1.3773064613342285 KL_init_x3: 0.09837187826633453  KL_init_v3: 0.09600590914487839
# ====> Epoch: 1549  Validation (rec. err.)^2: 20.3391  KL_z_aux9: 3.0458014011383057 KL_z_aux10: 0.19170798361301422 KL_c3: 0.03603473678231239 KL_k3: 1.5563106536865234 KL_init_x3: 0.03540169075131416  KL_init_v3: 0.03672210872173309
# ====> Epoch: 1550  Training (rec. err.)^2: 46.2111  KL_z_aux9: 2.932586193084717 KL_z_aux10: 0.17131564021110535 KL_m3: 0.5901302695274353  KL_c3: 0.09969056397676468 KL_k3: 1.4129942655563354 KL_init_x3: 0.09657874703407288  KL_init_v3: 0.10169006884098053
# ====> Epoch: 1550  Validation (rec. err.)^2: 20.0626  KL_z_aux9: 3.0503852367401123 KL_z_aux10: 0.1917668581008911 KL_c3: 0.035994499921798706 KL_k3: 1.5576173067092896 KL_init_x3: 0.03526751324534416  KL_init_v3: 0.037380386143922806
# ====> Epoch: 1551  Training (rec. err.)^2: 44.9612  KL_z_aux9: 2.957989454269409 KL_z_aux10: 0.1682785302400589 KL_m3: 0.5670846700668335  KL_c3: 0.0919642224907875 KL_k3: 1.4096105098724365 KL_init_x3: 0.09647645801305771  KL_init_v3: 0.10809911042451859
# ====> Epoch: 1551  Validation (rec. err.)^2: 19.6318  KL_z_aux9: 3.1108078956604004 KL_z_aux10: 0.19233198463916779 KL_c3: 0.03614368289709091 KL_k3: 1.558002233505249 KL_init_x3: 0.03521222621202469  KL_init_v3: 0.037909939885139465
# ====> Epoch: 1552  Training (rec. err.)^2: 45.7134  KL_z_aux9: 3.026200532913208 KL_z_aux10: 0.17086438834667206 KL_m3: 0.5681601762771606  KL_c3: 0.1033865213394165 KL_k3: 1.4033575057983398 KL_init_x3: 0.10170959681272507  KL_init_v3: 0.10580860078334808
# ====> Epoch: 1552  Validation (rec. err.)^2: 20.1136  KL_z_aux9: 3.139437437057495 KL_z_aux10: 0.1935187429189682 KL_c3: 0.03544873744249344 KL_k3: 1.5542593002319336 KL_init_x3: 0.0345158614218235  KL_init_v3: 0.037450287491083145
# ====> Epoch: 1553  Training (rec. err.)^2: 45.3279  KL_z_aux9: 2.996178150177002 KL_z_aux10: 0.16545316576957703 KL_m3: 0.5663179159164429  KL_c3: 0.08844848722219467 KL_k3: 1.4021633863449097 KL_init_x3: 0.09906236827373505  KL_init_v3: 0.09701231867074966
# ====> Epoch: 1553  Validation (rec. err.)^2: 20.2296  KL_z_aux9: 3.102562665939331 KL_z_aux10: 0.19373944401741028 KL_c3: 0.03372426703572273 KL_k3: 1.546568512916565 KL_init_x3: 0.032987527549266815  KL_init_v3: 0.03598658740520477
# ====> Epoch: 1554  Training (rec. err.)^2: 47.5162  KL_z_aux9: 2.9970312118530273 KL_z_aux10: 0.17353910207748413 KL_m3: 0.5610698461532593  KL_c3: 0.09784051775932312 KL_k3: 1.3880144357681274 KL_init_x3: 0.1009443998336792  KL_init_v3: 0.09118384122848511
# ====> Epoch: 1554  Validation (rec. err.)^2: 20.2498  KL_z_aux9: 3.161928415298462 KL_z_aux10: 0.19362488389015198 KL_c3: 0.03269113227725029 KL_k3: 1.5413106679916382 KL_init_x3: 0.03218719735741615  KL_init_v3: 0.035270191729068756
# ====> Epoch: 1555  Training (rec. err.)^2: 44.9538  KL_z_aux9: 3.093085289001465 KL_z_aux10: 0.17421919107437134 KL_m3: 0.5501192808151245  KL_c3: 0.09995042532682419 KL_k3: 1.3737399578094482 KL_init_x3: 0.09519936889410019  KL_init_v3: 0.09683604538440704
# ====> Epoch: 1555  Validation (rec. err.)^2: 19.9046  KL_z_aux9: 3.180237054824829 KL_z_aux10: 0.1940566748380661 KL_c3: 0.032084912061691284 KL_k3: 1.5387258529663086 KL_init_x3: 0.031534917652606964  KL_init_v3: 0.034556008875370026
# ====> Epoch: 1556  Training (rec. err.)^2: 44.4437  KL_z_aux9: 3.073643684387207 KL_z_aux10: 0.17894026637077332 KL_m3: 0.5603243112564087  KL_c3: 0.1071547418832779 KL_k3: 1.3629944324493408 KL_init_x3: 0.09922116249799728  KL_init_v3: 0.10119185596704483
# ====> Epoch: 1556  Validation (rec. err.)^2: 19.8500  KL_z_aux9: 3.1668457984924316 KL_z_aux10: 0.19501709938049316 KL_c3: 0.03226024657487869 KL_k3: 1.538525938987732 KL_init_x3: 0.03139695152640343  KL_init_v3: 0.034495759755373
# ====> Epoch: 1557  Training (rec. err.)^2: 43.0394  KL_z_aux9: 3.073267698287964 KL_z_aux10: 0.180583193898201 KL_m3: 0.5573098659515381  KL_c3: 0.09052539616823196 KL_k3: 1.3873910903930664 KL_init_x3: 0.09954538196325302  KL_init_v3: 0.10049837082624435
# ====> Epoch: 1557  Validation (rec. err.)^2: 20.0050  KL_z_aux9: 3.144733428955078 KL_z_aux10: 0.19593049585819244 KL_c3: 0.03150644153356552 KL_k3: 1.5331470966339111 KL_init_x3: 0.03045150451362133  KL_init_v3: 0.033624567091464996
# ====> Epoch: 1558  Training (rec. err.)^2: 45.0664  KL_z_aux9: 3.053213119506836 KL_z_aux10: 0.17704370617866516 KL_m3: 0.5628240704536438  KL_c3: 0.08793851733207703 KL_k3: 1.3699036836624146 KL_init_x3: 0.09780919551849365  KL_init_v3: 0.09528797119855881
# ====> Epoch: 1558  Validation (rec. err.)^2: 20.4562  KL_z_aux9: 3.109027147293091 KL_z_aux10: 0.1960337907075882 KL_c3: 0.030113354325294495 KL_k3: 1.52375328540802 KL_init_x3: 0.029070721939206123  KL_init_v3: 0.03228694573044777
# ====> Epoch: 1559  Training (rec. err.)^2: 44.8476  KL_z_aux9: 3.0328376293182373 KL_z_aux10: 0.17313557863235474 KL_m3: 0.5341580510139465  KL_c3: 0.09810684621334076 KL_k3: 1.3379385471343994 KL_init_x3: 0.10208795964717865  KL_init_v3: 0.09685085713863373
# ====> Epoch: 1559  Validation (rec. err.)^2: 20.0350  KL_z_aux9: 3.1509249210357666 KL_z_aux10: 0.19622817635536194 KL_c3: 0.029031191021203995 KL_k3: 1.5162632465362549 KL_init_x3: 0.028157386928796768  KL_init_v3: 0.03130720183253288
# ====> Epoch: 1560  Training (rec. err.)^2: 43.8693  KL_z_aux9: 3.0707173347473145 KL_z_aux10: 0.18077075481414795 KL_m3: 0.5268463492393494  KL_c3: 0.08718053251504898 KL_k3: 1.3492714166641235 KL_init_x3: 0.10380057990550995  KL_init_v3: 0.10519710183143616
# ====> Epoch: 1560  Validation (rec. err.)^2: 19.7652  KL_z_aux9: 3.145372152328491 KL_z_aux10: 0.19632551074028015 KL_c3: 0.027728531509637833 KL_k3: 1.5094163417816162 KL_init_x3: 0.02723708562552929  KL_init_v3: 0.030054792761802673
# ====> Epoch: 1561  Training (rec. err.)^2: 46.5082  KL_z_aux9: 3.021068811416626 KL_z_aux10: 0.18132545053958893 KL_m3: 0.5524716973304749  KL_c3: 0.0950280949473381 KL_k3: 1.3576126098632812 KL_init_x3: 0.09864531457424164  KL_init_v3: 0.10383526980876923
# ====> Epoch: 1561  Validation (rec. err.)^2: 19.9403  KL_z_aux9: 3.1173293590545654 KL_z_aux10: 0.19617944955825806 KL_c3: 0.02737807296216488 KL_k3: 1.5057438611984253 KL_init_x3: 0.027072317898273468  KL_init_v3: 0.029460042715072632
# ====> Epoch: 1562  Training (rec. err.)^2: 45.7375  KL_z_aux9: 2.998668670654297 KL_z_aux10: 0.17838743329048157 KL_m3: 0.5231480002403259  KL_c3: 0.08881156146526337 KL_k3: 1.3196444511413574 KL_init_x3: 0.10898615419864655  KL_init_v3: 0.09312152862548828
# ====> Epoch: 1562  Validation (rec. err.)^2: 20.0509  KL_z_aux9: 3.0822067260742188 KL_z_aux10: 0.19657671451568604 KL_c3: 0.027768423780798912 KL_k3: 1.5038745403289795 KL_init_x3: 0.027313290163874626  KL_init_v3: 0.02929253689944744
# ====> Epoch: 1563  Training (rec. err.)^2: 46.3025  KL_z_aux9: 3.025326728820801 KL_z_aux10: 0.17592565715312958 KL_m3: 0.5397395491600037  KL_c3: 0.09549496322870255 KL_k3: 1.3242769241333008 KL_init_x3: 0.09830493479967117  KL_init_v3: 0.09235097467899323
# ====> Epoch: 1563  Validation (rec. err.)^2: 20.0462  KL_z_aux9: 3.113380193710327 KL_z_aux10: 0.19704090058803558 KL_c3: 0.028998035937547684 KL_k3: 1.5036003589630127 KL_init_x3: 0.028180044144392014  KL_init_v3: 0.030053868889808655
# ====> Epoch: 1564  Training (rec. err.)^2: 43.4723  KL_z_aux9: 3.0780508518218994 KL_z_aux10: 0.17920050024986267 KL_m3: 0.5655677318572998  KL_c3: 0.09808813780546188 KL_k3: 1.3670669794082642 KL_init_x3: 0.09685267508029938  KL_init_v3: 0.09830710291862488
# ====> Epoch: 1564  Validation (rec. err.)^2: 20.0891  KL_z_aux9: 3.11739182472229 KL_z_aux10: 0.19713269174098969 KL_c3: 0.029900778084993362 KL_k3: 1.5023103952407837 KL_init_x3: 0.02883933112025261  KL_init_v3: 0.03066949173808098
# ====> Epoch: 1565  Training (rec. err.)^2: 44.1984  KL_z_aux9: 3.0336506366729736 KL_z_aux10: 0.17649313807487488 KL_m3: 0.5487332940101624  KL_c3: 0.08902681618928909 KL_k3: 1.3458690643310547 KL_init_x3: 0.10175056010484695  KL_init_v3: 0.10145322978496552
# ====> Epoch: 1565  Validation (rec. err.)^2: 20.1041  KL_z_aux9: 3.1006886959075928 KL_z_aux10: 0.19723111391067505 KL_c3: 0.030544856563210487 KL_k3: 1.5017306804656982 KL_init_x3: 0.02957901544868946  KL_init_v3: 0.031180761754512787
# ====> Epoch: 1566  Training (rec. err.)^2: 44.7203  KL_z_aux9: 2.998140335083008 KL_z_aux10: 0.18100884556770325 KL_m3: 0.5375837683677673  KL_c3: 0.086821049451828 KL_k3: 1.3428388833999634 KL_init_x3: 0.10569752752780914  KL_init_v3: 0.09537581354379654
# ====> Epoch: 1566  Validation (rec. err.)^2: 19.9593  KL_z_aux9: 3.118488311767578 KL_z_aux10: 0.19749462604522705 KL_c3: 0.032246507704257965 KL_k3: 1.506341814994812 KL_init_x3: 0.031040899455547333  KL_init_v3: 0.032418087124824524
# ====> Epoch: 1567  Training (rec. err.)^2: 46.2784  KL_z_aux9: 2.995091438293457 KL_z_aux10: 0.18295831978321075 KL_m3: 0.5463376641273499  KL_c3: 0.09145131707191467 KL_k3: 1.322791576385498 KL_init_x3: 0.09369386732578278  KL_init_v3: 0.09295536577701569
# ====> Epoch: 1567  Validation (rec. err.)^2: 19.8796  KL_z_aux9: 3.14286208152771 KL_z_aux10: 0.19806964695453644 KL_c3: 0.03427394479513168 KL_k3: 1.5137585401535034 KL_init_x3: 0.03276766464114189  KL_init_v3: 0.03400291129946709
# ====> Epoch: 1568  Training (rec. err.)^2: 45.6496  KL_z_aux9: 3.0255355834960938 KL_z_aux10: 0.17870774865150452 KL_m3: 0.5717657804489136  KL_c3: 0.09472706913948059 KL_k3: 1.3501092195510864 KL_init_x3: 0.10411679744720459  KL_init_v3: 0.09668180346488953
# ====> Epoch: 1568  Validation (rec. err.)^2: 19.8664  KL_z_aux9: 3.142899751663208 KL_z_aux10: 0.19900819659233093 KL_c3: 0.03455943241715431 KL_k3: 1.5154478549957275 KL_init_x3: 0.03318771347403526  KL_init_v3: 0.03394511714577675
# ====> Epoch: 1569  Training (rec. err.)^2: 45.9277  KL_z_aux9: 3.0443949699401855 KL_z_aux10: 0.1835279017686844 KL_m3: 0.5809921026229858  KL_c3: 0.08898451924324036 KL_k3: 1.3943697214126587 KL_init_x3: 0.08922933042049408  KL_init_v3: 0.08896960318088531
# ====> Epoch: 1569  Validation (rec. err.)^2: 20.5243  KL_z_aux9: 3.095280885696411 KL_z_aux10: 0.20001345872879028 KL_c3: 0.03439692035317421 KL_k3: 1.5151780843734741 KL_init_x3: 0.03333596885204315  KL_init_v3: 0.03345051780343056
# ====> Epoch: 1570  Training (rec. err.)^2: 46.7489  KL_z_aux9: 2.973024845123291 KL_z_aux10: 0.1821897178888321 KL_m3: 0.5584920048713684  KL_c3: 0.08967088907957077 KL_k3: 1.3616101741790771 KL_init_x3: 0.0879908874630928  KL_init_v3: 0.09076147526502609
# ====> Epoch: 1570  Validation (rec. err.)^2: 20.1885  KL_z_aux9: 3.1289825439453125 KL_z_aux10: 0.20139655470848083 KL_c3: 0.03510276973247528 KL_k3: 1.5158945322036743 KL_init_x3: 0.0341319665312767  KL_init_v3: 0.03362393379211426
# ====> Epoch: 1571  Training (rec. err.)^2: 46.0898  KL_z_aux9: 3.0454375743865967 KL_z_aux10: 0.18165479600429535 KL_m3: 0.5731670260429382  KL_c3: 0.09805562347173691 KL_k3: 1.3675044775009155 KL_init_x3: 0.10395052284002304  KL_init_v3: 0.1012830063700676
# ====> Epoch: 1571  Validation (rec. err.)^2: 19.8843  KL_z_aux9: 3.2095296382904053 KL_z_aux10: 0.20237207412719727 KL_c3: 0.03633725270628929 KL_k3: 1.5179507732391357 KL_init_x3: 0.035280607640743256  KL_init_v3: 0.03475017845630646
# ====> Epoch: 1572  Training (rec. err.)^2: 47.6070  KL_z_aux9: 3.1344006061553955 KL_z_aux10: 0.18555530905723572 KL_m3: 0.591008722782135  KL_c3: 0.09225355833768845 KL_k3: 1.3437857627868652 KL_init_x3: 0.08957938104867935  KL_init_v3: 0.09535550326108932
# ====> Epoch: 1572  Validation (rec. err.)^2: 19.8387  KL_z_aux9: 3.2141988277435303 KL_z_aux10: 0.2036936730146408 KL_c3: 0.03719814494252205 KL_k3: 1.5188630819320679 KL_init_x3: 0.03588622435927391  KL_init_v3: 0.03559182956814766
# ====> Epoch: 1573  Training (rec. err.)^2: 43.0861  KL_z_aux9: 3.096379041671753 KL_z_aux10: 0.1792600154876709 KL_m3: 0.6024510264396667  KL_c3: 0.09133969992399216 KL_k3: 1.3731328248977661 KL_init_x3: 0.09996722638607025  KL_init_v3: 0.09034064412117004
# ====> Epoch: 1573  Validation (rec. err.)^2: 20.1740  KL_z_aux9: 3.175786256790161 KL_z_aux10: 0.20451301336288452 KL_c3: 0.03649511933326721 KL_k3: 1.5149391889572144 KL_init_x3: 0.03535105288028717  KL_init_v3: 0.03518989682197571
# ====> Epoch: 1574  Training (rec. err.)^2: 46.0577  KL_z_aux9: 3.0227136611938477 KL_z_aux10: 0.1894877403974533 KL_m3: 0.5724581480026245  KL_c3: 0.0917668491601944 KL_k3: 1.369498610496521 KL_init_x3: 0.09411570429801941  KL_init_v3: 0.0939464122056961
# ====> Epoch: 1574  Validation (rec. err.)^2: 20.1000  KL_z_aux9: 3.1983442306518555 KL_z_aux10: 0.20516610145568848 KL_c3: 0.03502018377184868 KL_k3: 1.5105466842651367 KL_init_x3: 0.03432738780975342  KL_init_v3: 0.034041520208120346
# ====> Epoch: 1575  Training (rec. err.)^2: 43.6397  KL_z_aux9: 3.1199147701263428 KL_z_aux10: 0.18561775982379913 KL_m3: 0.5875996351242065  KL_c3: 0.0876559168100357 KL_k3: 1.3965479135513306 KL_init_x3: 0.09525939077138901  KL_init_v3: 0.10476399213075638
# ====> Epoch: 1575  Validation (rec. err.)^2: 20.3498  KL_z_aux9: 3.1740989685058594 KL_z_aux10: 0.20542274415493011 KL_c3: 0.03384701535105705 KL_k3: 1.5085628032684326 KL_init_x3: 0.03333720937371254  KL_init_v3: 0.03320104256272316
# ====> Epoch: 1576  Training (rec. err.)^2: 44.3879  KL_z_aux9: 3.0388810634613037 KL_z_aux10: 0.18911008536815643 KL_m3: 0.5646519660949707  KL_c3: 0.09878867119550705 KL_k3: 1.3733769655227661 KL_init_x3: 0.09531345218420029  KL_init_v3: 0.085069939494133
# ====> Epoch: 1576  Validation (rec. err.)^2: 19.9780  KL_z_aux9: 3.180482864379883 KL_z_aux10: 0.20554184913635254 KL_c3: 0.032994192093610764 KL_k3: 1.5068000555038452 KL_init_x3: 0.032565172761678696  KL_init_v3: 0.03267578408122063
# ====> Epoch: 1577  Training (rec. err.)^2: 44.6549  KL_z_aux9: 3.082444906234741 KL_z_aux10: 0.18647953867912292 KL_m3: 0.5514718294143677  KL_c3: 0.08961227536201477 KL_k3: 1.3209303617477417 KL_init_x3: 0.09824083000421524  KL_init_v3: 0.09055749326944351
# ====> Epoch: 1577  Validation (rec. err.)^2: 20.0860  KL_z_aux9: 3.1587843894958496 KL_z_aux10: 0.20569294691085815 KL_c3: 0.03291630744934082 KL_k3: 1.5055874586105347 KL_init_x3: 0.032291535288095474  KL_init_v3: 0.032706309109926224
# ====> Epoch: 1578  Training (rec. err.)^2: 45.3034  KL_z_aux9: 3.074460029602051 KL_z_aux10: 0.1845591813325882 KL_m3: 0.5801158547401428  KL_c3: 0.08957725763320923 KL_k3: 1.35518217086792 KL_init_x3: 0.09624195843935013  KL_init_v3: 0.09311576187610626
# ====> Epoch: 1578  Validation (rec. err.)^2: 20.3777  KL_z_aux9: 3.136000156402588 KL_z_aux10: 0.2055334746837616 KL_c3: 0.03309148550033569 KL_k3: 1.5035011768341064 KL_init_x3: 0.03186576068401337  KL_init_v3: 0.032892871648073196
# ====> Epoch: 1579  Training (rec. err.)^2: 45.5902  KL_z_aux9: 3.0070748329162598 KL_z_aux10: 0.18613219261169434 KL_m3: 0.5640165209770203  KL_c3: 0.0915222242474556 KL_k3: 1.3409807682037354 KL_init_x3: 0.09503427892923355  KL_init_v3: 0.09205804765224457
# ====> Epoch: 1579  Validation (rec. err.)^2: 19.9841  KL_z_aux9: 3.163588523864746 KL_z_aux10: 0.2056981772184372 KL_c3: 0.034116193652153015 KL_k3: 1.505679726600647 KL_init_x3: 0.03212197870016098  KL_init_v3: 0.03382597491145134
# ====> Epoch: 1580  Training (rec. err.)^2: 44.2544  KL_z_aux9: 3.072636127471924 KL_z_aux10: 0.1883007287979126 KL_m3: 0.538446307182312  KL_c3: 0.09818936884403229 KL_k3: 1.352792739868164 KL_init_x3: 0.09479399770498276  KL_init_v3: 0.09758613258600235
# ====> Epoch: 1580  Validation (rec. err.)^2: 19.8934  KL_z_aux9: 3.190457344055176 KL_z_aux10: 0.20548370480537415 KL_c3: 0.0343887098133564 KL_k3: 1.5073230266571045 KL_init_x3: 0.03215978667140007  KL_init_v3: 0.03420211747288704
# ====> Epoch: 1581  Training (rec. err.)^2: 45.6736  KL_z_aux9: 3.0778934955596924 KL_z_aux10: 0.1853996068239212 KL_m3: 0.5602487325668335  KL_c3: 0.09489348530769348 KL_k3: 1.3519424200057983 KL_init_x3: 0.09863835573196411  KL_init_v3: 0.09596916288137436
# ====> Epoch: 1581  Validation (rec. err.)^2: 20.1813  KL_z_aux9: 3.198349714279175 KL_z_aux10: 0.20557358860969543 KL_c3: 0.03362896293401718 KL_k3: 1.5056265592575073 KL_init_x3: 0.03142781928181648  KL_init_v3: 0.033538881689310074
# ====> Epoch: 1582  Training (rec. err.)^2: 47.3055  KL_z_aux9: 3.051866292953491 KL_z_aux10: 0.18817627429962158 KL_m3: 0.5575119853019714  KL_c3: 0.09199118614196777 KL_k3: 1.358203411102295 KL_init_x3: 0.09714116156101227  KL_init_v3: 0.09746702760457993
# ====> Epoch: 1582  Validation (rec. err.)^2: 19.7197  KL_z_aux9: 3.173205614089966 KL_z_aux10: 0.20476531982421875 KL_c3: 0.03173375129699707 KL_k3: 1.500129222869873 KL_init_x3: 0.030066000297665596  KL_init_v3: 0.03188494220376015
# ====> Epoch: 1583  Training (rec. err.)^2: 43.7517  KL_z_aux9: 3.024392604827881 KL_z_aux10: 0.18570490181446075 KL_m3: 0.5477555394172668  KL_c3: 0.0943242758512497 KL_k3: 1.3723064661026 KL_init_x3: 0.09523315727710724  KL_init_v3: 0.10296840965747833
# ====> Epoch: 1583  Validation (rec. err.)^2: 19.8784  KL_z_aux9: 3.14825701713562 KL_z_aux10: 0.20327900350093842 KL_c3: 0.03037170134484768 KL_k3: 1.4946584701538086 KL_init_x3: 0.029225317761301994  KL_init_v3: 0.030681895092129707
# ====> Epoch: 1584  Training (rec. err.)^2: 44.5180  KL_z_aux9: 2.997507095336914 KL_z_aux10: 0.18643686175346375 KL_m3: 0.5522878766059875  KL_c3: 0.09788095206022263 KL_k3: 1.3371416330337524 KL_init_x3: 0.10193650424480438  KL_init_v3: 0.09021168202161789
# ====> Epoch: 1584  Validation (rec. err.)^2: 20.0564  KL_z_aux9: 3.1194894313812256 KL_z_aux10: 0.2019510269165039 KL_c3: 0.029924912378191948 KL_k3: 1.4916914701461792 KL_init_x3: 0.028880592435598373  KL_init_v3: 0.030096353963017464
# ====> Epoch: 1585  Training (rec. err.)^2: 45.4174  KL_z_aux9: 3.00675106048584 KL_z_aux10: 0.18275372684001923 KL_m3: 0.554462730884552  KL_c3: 0.09030081331729889 KL_k3: 1.3465328216552734 KL_init_x3: 0.0956825390458107  KL_init_v3: 0.09170831739902496
# ====> Epoch: 1585  Validation (rec. err.)^2: 19.9383  KL_z_aux9: 3.179663896560669 KL_z_aux10: 0.2000698745250702 KL_c3: 0.03082369454205036 KL_k3: 1.4902688264846802 KL_init_x3: 0.029327744618058205  KL_init_v3: 0.030500371009111404
# ====> Epoch: 1586  Training (rec. err.)^2: 44.3204  KL_z_aux9: 3.090599536895752 KL_z_aux10: 0.1785682886838913 KL_m3: 0.5728356838226318  KL_c3: 0.0874292328953743 KL_k3: 1.3451067209243774 KL_init_x3: 0.09745360165834427  KL_init_v3: 0.09625593572854996
# ====> Epoch: 1586  Validation (rec. err.)^2: 19.9700  KL_z_aux9: 3.162677526473999 KL_z_aux10: 0.1980544775724411 KL_c3: 0.031855739653110504 KL_k3: 1.4919548034667969 KL_init_x3: 0.029825733974575996  KL_init_v3: 0.031076600775122643
# ====> Epoch: 1587  Training (rec. err.)^2: 42.4136  KL_z_aux9: 3.045402765274048 KL_z_aux10: 0.18167850375175476 KL_m3: 0.5611978769302368  KL_c3: 0.0881604477763176 KL_k3: 1.3201805353164673 KL_init_x3: 0.09965849667787552  KL_init_v3: 0.10024179518222809
# ====> Epoch: 1587  Validation (rec. err.)^2: 20.0252  KL_z_aux9: 3.087055206298828 KL_z_aux10: 0.19594889879226685 KL_c3: 0.03132383152842522 KL_k3: 1.4896316528320312 KL_init_x3: 0.029317934066057205  KL_init_v3: 0.030572708696126938
# ====> Epoch: 1588  Training (rec. err.)^2: 45.7516  KL_z_aux9: 3.0036773681640625 KL_z_aux10: 0.17613185942173004 KL_m3: 0.555504322052002  KL_c3: 0.08835948258638382 KL_k3: 1.3180577754974365 KL_init_x3: 0.10000249743461609  KL_init_v3: 0.09315603971481323
# ====> Epoch: 1588  Validation (rec. err.)^2: 19.9985  KL_z_aux9: 3.0880205631256104 KL_z_aux10: 0.1945439875125885 KL_c3: 0.0314597450196743 KL_k3: 1.491666555404663 KL_init_x3: 0.02960021048784256  KL_init_v3: 0.0308237262070179
# ====> Epoch: 1589  Training (rec. err.)^2: 43.2340  KL_z_aux9: 2.9770946502685547 KL_z_aux10: 0.18006664514541626 KL_m3: 0.5493530631065369  KL_c3: 0.09791695326566696 KL_k3: 1.3414063453674316 KL_init_x3: 0.1039058044552803  KL_init_v3: 0.09716490656137466
# ====> Epoch: 1589  Validation (rec. err.)^2: 20.0557  KL_z_aux9: 3.103620767593384 KL_z_aux10: 0.19350668787956238 KL_c3: 0.03226207569241524 KL_k3: 1.4963561296463013 KL_init_x3: 0.0304428543895483  KL_init_v3: 0.03159181773662567
# ====> Epoch: 1590  Training (rec. err.)^2: 42.9449  KL_z_aux9: 3.0186045169830322 KL_z_aux10: 0.17624154686927795 KL_m3: 0.5860956907272339  KL_c3: 0.09408041834831238 KL_k3: 1.3248794078826904 KL_init_x3: 0.09303053468465805  KL_init_v3: 0.0963846817612648
# ====> Epoch: 1590  Validation (rec. err.)^2: 19.9040  KL_z_aux9: 3.1022422313690186 KL_z_aux10: 0.1930294781923294 KL_c3: 0.03269873932003975 KL_k3: 1.501145362854004 KL_init_x3: 0.030911976471543312  KL_init_v3: 0.03199910372495651
# ====> Epoch: 1591  Training (rec. err.)^2: 43.1016  KL_z_aux9: 2.9634170532226562 KL_z_aux10: 0.17302729189395905 KL_m3: 0.573724627494812  KL_c3: 0.0959467887878418 KL_k3: 1.371089220046997 KL_init_x3: 0.09334979951381683  KL_init_v3: 0.09264343976974487
# ====> Epoch: 1591  Validation (rec. err.)^2: 20.0236  KL_z_aux9: 3.111818552017212 KL_z_aux10: 0.19315451383590698 KL_c3: 0.03253655880689621 KL_k3: 1.5031120777130127 KL_init_x3: 0.03100759908556938  KL_init_v3: 0.03197783976793289
# ====> Epoch: 1592  Training (rec. err.)^2: 43.2723  KL_z_aux9: 2.996255397796631 KL_z_aux10: 0.17170032858848572 KL_m3: 0.5735257863998413  KL_c3: 0.08555389195680618 KL_k3: 1.3639233112335205 KL_init_x3: 0.09875807911157608  KL_init_v3: 0.09489366412162781
# ====> Epoch: 1592  Validation (rec. err.)^2: 20.0249  KL_z_aux9: 3.084106922149658 KL_z_aux10: 0.19307419657707214 KL_c3: 0.031407758593559265 KL_k3: 1.5030044317245483 KL_init_x3: 0.030636804178357124  KL_init_v3: 0.031577158719301224
# ====> Epoch: 1593  Training (rec. err.)^2: 45.7012  KL_z_aux9: 2.980083465576172 KL_z_aux10: 0.16920116543769836 KL_m3: 0.5556426048278809  KL_c3: 0.09007851034402847 KL_k3: 1.340964913368225 KL_init_x3: 0.09456390142440796  KL_init_v3: 0.09465974569320679
# ====> Epoch: 1593  Validation (rec. err.)^2: 19.9721  KL_z_aux9: 3.1066110134124756 KL_z_aux10: 0.1932261437177658 KL_c3: 0.031246988102793694 KL_k3: 1.5049526691436768 KL_init_x3: 0.030776407569646835  KL_init_v3: 0.03196517005562782
# ====> Epoch: 1594  Training (rec. err.)^2: 43.8033  KL_z_aux9: 2.9712717533111572 KL_z_aux10: 0.16959986090660095 KL_m3: 0.5808210968971252  KL_c3: 0.09761741012334824 KL_k3: 1.3645669221878052 KL_init_x3: 0.09623295813798904  KL_init_v3: 0.09109658002853394
# ====> Epoch: 1594  Validation (rec. err.)^2: 19.8786  KL_z_aux9: 3.106949806213379 KL_z_aux10: 0.19282615184783936 KL_c3: 0.03131731599569321 KL_k3: 1.5061014890670776 KL_init_x3: 0.031287383288145065  KL_init_v3: 0.03240558132529259
# ====> Epoch: 1595  Training (rec. err.)^2: 45.1123  KL_z_aux9: 2.9944093227386475 KL_z_aux10: 0.17434433102607727 KL_m3: 0.5595694184303284  KL_c3: 0.09834051132202148 KL_k3: 1.337575912475586 KL_init_x3: 0.0959431529045105  KL_init_v3: 0.09211865812540054
# ====> Epoch: 1595  Validation (rec. err.)^2: 20.0397  KL_z_aux9: 3.0763752460479736 KL_z_aux10: 0.19283713400363922 KL_c3: 0.03163767233490944 KL_k3: 1.509949803352356 KL_init_x3: 0.03199990093708038  KL_init_v3: 0.03295442834496498
# ====> Epoch: 1596  Training (rec. err.)^2: 44.4697  KL_z_aux9: 2.9225709438323975 KL_z_aux10: 0.17444071173667908 KL_m3: 0.5892504453659058  KL_c3: 0.09440430253744125 KL_k3: 1.3724027872085571 KL_init_x3: 0.10526371747255325  KL_init_v3: 0.09734322130680084
# ====> Epoch: 1596  Validation (rec. err.)^2: 19.8861  KL_z_aux9: 3.076592445373535 KL_z_aux10: 0.1931588500738144 KL_c3: 0.03215540945529938 KL_k3: 1.515031099319458 KL_init_x3: 0.0330059751868248  KL_init_v3: 0.033455707132816315
# ====> Epoch: 1597  Training (rec. err.)^2: 43.7469  KL_z_aux9: 2.9914464950561523 KL_z_aux10: 0.17166654765605927 KL_m3: 0.5456136465072632  KL_c3: 0.0944121852517128 KL_k3: 1.3778173923492432 KL_init_x3: 0.1059858575463295  KL_init_v3: 0.08306840807199478
# ====> Epoch: 1597  Validation (rec. err.)^2: 19.9191  KL_z_aux9: 3.133445978164673 KL_z_aux10: 0.19370988011360168 KL_c3: 0.03245905041694641 KL_k3: 1.518897294998169 KL_init_x3: 0.03372474014759064  KL_init_v3: 0.033568788319826126
# ====> Epoch: 1598  Training (rec. err.)^2: 45.6465  KL_z_aux9: 3.035343885421753 KL_z_aux10: 0.17575544118881226 KL_m3: 0.5752823948860168  KL_c3: 0.08937044441699982 KL_k3: 1.3770846128463745 KL_init_x3: 0.09773886203765869  KL_init_v3: 0.08978014439344406
# ====> Epoch: 1598  Validation (rec. err.)^2: 19.7019  KL_z_aux9: 3.1197121143341064 KL_z_aux10: 0.19360339641571045 KL_c3: 0.03270472213625908 KL_k3: 1.5232471227645874 KL_init_x3: 0.034058913588523865  KL_init_v3: 0.03352390602231026
# ====> Epoch: 1599  Training (rec. err.)^2: 44.4784  KL_z_aux9: 2.992098808288574 KL_z_aux10: 0.1750262826681137 KL_m3: 0.5513408780097961  KL_c3: 0.0960400253534317 KL_k3: 1.3700008392333984 KL_init_x3: 0.09339409321546555  KL_init_v3: 0.09344037622213364
# ...
# ====> Epoch: 3969  Training (rec. err.)^2: 18.8396  KL_z_aux9: 2.7512221336364746 KL_z_aux10: 0.03541836887598038 KL_m3: 1.7162436246871948  KL_c3: 0.049554288387298584 KL_k3: 1.2580476999282837 KL_init_x3: 0.04285993427038193  KL_init_v3: 0.04283549636602402
# ====> Epoch: 3969  Validation (rec. err.)^2: 6.6832  KL_z_aux9: 2.789517879486084 KL_z_aux10: 0.03616584837436676 KL_c3: 0.01654232293367386 KL_k3: 1.3288605213165283 KL_init_x3: 0.017246363684535027  KL_init_v3: 0.012154359370470047
# ====> Epoch: 3970  Training (rec. err.)^2: 18.4888  KL_z_aux9: 2.7402939796447754 KL_z_aux10: 0.0342317633330822 KL_m3: 1.7472751140594482  KL_c3: 0.04695086181163788 KL_k3: 1.2578916549682617 KL_init_x3: 0.04477282240986824  KL_init_v3: 0.044679347425699234
# ====> Epoch: 3970  Validation (rec. err.)^2: 6.8736  KL_z_aux9: 2.7788712978363037 KL_z_aux10: 0.03534227982163429 KL_c3: 0.014907662756741047 KL_k3: 1.3238930702209473 KL_init_x3: 0.015536253340542316  KL_init_v3: 0.011331100948154926
# ====> Epoch: 3971  Training (rec. err.)^2: 17.5906  KL_z_aux9: 2.6912314891815186 KL_z_aux10: 0.033533886075019836 KL_m3: 1.7430800199508667  KL_c3: 0.046843044459819794 KL_k3: 1.2645784616470337 KL_init_x3: 0.04338618740439415  KL_init_v3: 0.04566922411322594
# ====> Epoch: 3971  Validation (rec. err.)^2: 6.3404  KL_z_aux9: 2.7985010147094727 KL_z_aux10: 0.034788571298122406 KL_c3: 0.01734582521021366 KL_k3: 1.3356138467788696 KL_init_x3: 0.01867336966097355  KL_init_v3: 0.014089935459196568
# ====> Epoch: 3972  Training (rec. err.)^2: 18.3004  KL_z_aux9: 2.7347350120544434 KL_z_aux10: 0.033592723309993744 KL_m3: 1.7254834175109863  KL_c3: 0.045096397399902344 KL_k3: 1.267496943473816 KL_init_x3: 0.04407353326678276  KL_init_v3: 0.044662460684776306
# ====> Epoch: 3972  Validation (rec. err.)^2: 6.4454  KL_z_aux9: 2.830974817276001 KL_z_aux10: 0.03417157009243965 KL_c3: 0.01484476774930954 KL_k3: 1.3209493160247803 KL_init_x3: 0.015981124714016914  KL_init_v3: 0.012006739154458046
# ====> Epoch: 3973  Training (rec. err.)^2: 17.8381  KL_z_aux9: 2.7699198722839355 KL_z_aux10: 0.03278475999832153 KL_m3: 1.7048816680908203  KL_c3: 0.04854782298207283 KL_k3: 1.259217381477356 KL_init_x3: 0.043774135410785675  KL_init_v3: 0.04469332471489906
# ====> Epoch: 3973  Validation (rec. err.)^2: 7.5575  KL_z_aux9: 2.8630361557006836 KL_z_aux10: 0.03337496891617775 KL_c3: 0.014494416303932667 KL_k3: 1.319934606552124 KL_init_x3: 0.016002457588911057  KL_init_v3: 0.012028666213154793
# ====> Epoch: 3974  Training (rec. err.)^2: 17.3152  KL_z_aux9: 2.798977851867676 KL_z_aux10: 0.03219727426767349 KL_m3: 1.7212730646133423  KL_c3: 0.04526034742593765 KL_k3: 1.2477812767028809 KL_init_x3: 0.0471719428896904  KL_init_v3: 0.04176491126418114
# ====> Epoch: 3974  Validation (rec. err.)^2: 6.5975  KL_z_aux9: 2.863507032394409 KL_z_aux10: 0.03314853459596634 KL_c3: 0.016349446028470993 KL_k3: 1.3339961767196655 KL_init_x3: 0.018399832770228386  KL_init_v3: 0.014174721203744411
# ====> Epoch: 3975  Training (rec. err.)^2: 17.5982  KL_z_aux9: 2.792015314102173 KL_z_aux10: 0.03201224282383919 KL_m3: 1.7240138053894043  KL_c3: 0.049270693212747574 KL_k3: 1.2468726634979248 KL_init_x3: 0.047613926231861115  KL_init_v3: 0.0455419197678566
# ====> Epoch: 3975  Validation (rec. err.)^2: 6.4720  KL_z_aux9: 2.825845241546631 KL_z_aux10: 0.03291121870279312 KL_c3: 0.010707998648285866 KL_k3: 1.306185245513916 KL_init_x3: 0.011611271649599075  KL_init_v3: 0.008915587328374386
# ====> Epoch: 3976  Training (rec. err.)^2: 18.0638  KL_z_aux9: 2.75569748878479 KL_z_aux10: 0.031905971467494965 KL_m3: 1.6545714139938354  KL_c3: 0.04469781741499901 KL_k3: 1.2325273752212524 KL_init_x3: 0.045395128428936005  KL_init_v3: 0.04471729323267937
# ====> Epoch: 3976  Validation (rec. err.)^2: 7.0164  KL_z_aux9: 2.7848246097564697 KL_z_aux10: 0.03248593211174011 KL_c3: 0.009540987201035023 KL_k3: 1.300187587738037 KL_init_x3: 0.010104096494615078  KL_init_v3: 0.007875891402363777
# ====> Epoch: 3977  Training (rec. err.)^2: 17.7494  KL_z_aux9: 2.7193853855133057 KL_z_aux10: 0.03305502608418465 KL_m3: 1.6853994131088257  KL_c3: 0.04339118301868439 KL_k3: 1.2161648273468018 KL_init_x3: 0.039255186915397644  KL_init_v3: 0.043163079768419266
# ====> Epoch: 3977  Validation (rec. err.)^2: 6.9862  KL_z_aux9: 2.77624773979187 KL_z_aux10: 0.032410722225904465 KL_c3: 0.013307015411555767 KL_k3: 1.3168319463729858 KL_init_x3: 0.01467046607285738  KL_init_v3: 0.011459551751613617
# ====> Epoch: 3978  Training (rec. err.)^2: 17.4840  KL_z_aux9: 2.7052290439605713 KL_z_aux10: 0.0318477563560009 KL_m3: 1.6797739267349243  KL_c3: 0.0443173423409462 KL_k3: 1.2424548864364624 KL_init_x3: 0.04467234015464783  KL_init_v3: 0.047887761145830154
# ====> Epoch: 3978  Validation (rec. err.)^2: 6.4582  KL_z_aux9: 2.8002383708953857 KL_z_aux10: 0.032366540282964706 KL_c3: 0.010541870258748531 KL_k3: 1.2938556671142578 KL_init_x3: 0.011412168852984905  KL_init_v3: 0.008751611225306988
# ====> Epoch: 3979  Training (rec. err.)^2: 17.1835  KL_z_aux9: 2.7241172790527344 KL_z_aux10: 0.032502464950084686 KL_m3: 1.5719265937805176  KL_c3: 0.0459841713309288 KL_k3: 1.2217576503753662 KL_init_x3: 0.03979874029755592  KL_init_v3: 0.04495784267783165
# ====> Epoch: 3979  Validation (rec. err.)^2: 6.9024  KL_z_aux9: 2.8056724071502686 KL_z_aux10: 0.032214973121881485 KL_c3: 0.010248123668134212 KL_k3: 1.28602135181427 KL_init_x3: 0.01086251251399517  KL_init_v3: 0.00801418162882328
# ====> Epoch: 3980  Training (rec. err.)^2: 17.1893  KL_z_aux9: 2.771167278289795 KL_z_aux10: 0.03203003108501434 KL_m3: 1.6200085878372192  KL_c3: 0.04442591220140457 KL_k3: 1.2383145093917847 KL_init_x3: 0.045005906373262405  KL_init_v3: 0.045480187982320786
# ====> Epoch: 3980  Validation (rec. err.)^2: 6.4086  KL_z_aux9: 2.7734642028808594 KL_z_aux10: 0.032341618090867996 KL_c3: 0.013472176156938076 KL_k3: 1.2954736948013306 KL_init_x3: 0.014289963990449905  KL_init_v3: 0.010338995605707169
# ====> Epoch: 3981  Training (rec. err.)^2: 16.8028  KL_z_aux9: 2.7218096256256104 KL_z_aux10: 0.03208160027861595 KL_m3: 1.6608082056045532  KL_c3: 0.047436248511075974 KL_k3: 1.2215274572372437 KL_init_x3: 0.046696655452251434  KL_init_v3: 0.047415729612112045
# ====> Epoch: 3981  Validation (rec. err.)^2: 6.5509  KL_z_aux9: 2.74164080619812 KL_z_aux10: 0.03233376890420914 KL_c3: 0.012624407187104225 KL_k3: 1.281546950340271 KL_init_x3: 0.01284086611121893  KL_init_v3: 0.009179327636957169
# ====> Epoch: 3982  Training (rec. err.)^2: 19.6001  KL_z_aux9: 2.6630783081054688 KL_z_aux10: 0.031003346666693687 KL_m3: 1.633023977279663  KL_c3: 0.044131144881248474 KL_k3: 1.223811388015747 KL_init_x3: 0.04505697637796402  KL_init_v3: 0.046048473566770554
# ====> Epoch: 3982  Validation (rec. err.)^2: 6.6873  KL_z_aux9: 2.7435312271118164 KL_z_aux10: 0.032843124121427536 KL_c3: 0.013702115043997765 KL_k3: 1.2820576429367065 KL_init_x3: 0.013911286368966103  KL_init_v3: 0.009731169790029526
# ====> Epoch: 3983  Training (rec. err.)^2: 18.3293  KL_z_aux9: 2.6802520751953125 KL_z_aux10: 0.03223184496164322 KL_m3: 1.678330898284912  KL_c3: 0.044418878853321075 KL_k3: 1.2036362886428833 KL_init_x3: 0.04577609524130821  KL_init_v3: 0.04491853713989258
# ====> Epoch: 3983  Validation (rec. err.)^2: 6.2837  KL_z_aux9: 2.755749225616455 KL_z_aux10: 0.0333499014377594 KL_c3: 0.017558258026838303 KL_k3: 1.2983124256134033 KL_init_x3: 0.01800341159105301  KL_init_v3: 0.01293798629194498
# ====> Epoch: 3984  Training (rec. err.)^2: 18.0310  KL_z_aux9: 2.688359022140503 KL_z_aux10: 0.03428054228425026 KL_m3: 1.7261631488800049  KL_c3: 0.04604052007198334 KL_k3: 1.2242263555526733 KL_init_x3: 0.04420963674783707  KL_init_v3: 0.044394560158252716
# ====> Epoch: 3984  Validation (rec. err.)^2: 6.2117  KL_z_aux9: 2.7634787559509277 KL_z_aux10: 0.033922575414180756 KL_c3: 0.018561217933893204 KL_k3: 1.3038920164108276 KL_init_x3: 0.01880311220884323  KL_init_v3: 0.013589625246822834
# ====> Epoch: 3985  Training (rec. err.)^2: 16.9700  KL_z_aux9: 2.7000277042388916 KL_z_aux10: 0.033366233110427856 KL_m3: 1.7843927145004272  KL_c3: 0.046614039689302444 KL_k3: 1.2445753812789917 KL_init_x3: 0.04935694485902786  KL_init_v3: 0.044278886169195175
# ====> Epoch: 3985  Validation (rec. err.)^2: 6.4982  KL_z_aux9: 2.7745983600616455 KL_z_aux10: 0.034404389560222626 KL_c3: 0.01792428269982338 KL_k3: 1.3014700412750244 KL_init_x3: 0.017640331760048866  KL_init_v3: 0.01299051009118557
# ====> Epoch: 3986  Training (rec. err.)^2: 17.9194  KL_z_aux9: 2.723233461380005 KL_z_aux10: 0.03332449868321419 KL_m3: 1.7470630407333374  KL_c3: 0.04832673817873001 KL_k3: 1.2347416877746582 KL_init_x3: 0.04577644169330597  KL_init_v3: 0.04443838819861412
# ====> Epoch: 3986  Validation (rec. err.)^2: 6.2471  KL_z_aux9: 2.7817609310150146 KL_z_aux10: 0.03472860902547836 KL_c3: 0.018405308946967125 KL_k3: 1.2986589670181274 KL_init_x3: 0.01788077875971794  KL_init_v3: 0.013524224050343037
# ====> Epoch: 3987  Training (rec. err.)^2: 17.2446  KL_z_aux9: 2.696589708328247 KL_z_aux10: 0.03402721881866455 KL_m3: 1.7840638160705566  KL_c3: 0.04512690752744675 KL_k3: 1.223850965499878 KL_init_x3: 0.04388963431119919  KL_init_v3: 0.04266170784831047
# ====> Epoch: 3987  Validation (rec. err.)^2: 6.2352  KL_z_aux9: 2.781400442123413 KL_z_aux10: 0.034666839987039566 KL_c3: 0.017526736482977867 KL_k3: 1.2913572788238525 KL_init_x3: 0.017087604850530624  KL_init_v3: 0.012780052609741688
# ====> Epoch: 3988  Training (rec. err.)^2: 17.9782  KL_z_aux9: 2.7093019485473633 KL_z_aux10: 0.03405184671282768 KL_m3: 1.7443253993988037  KL_c3: 0.04390845075249672 KL_k3: 1.212870717048645 KL_init_x3: 0.04752093553543091  KL_init_v3: 0.04923306033015251
# ====> Epoch: 3988  Validation (rec. err.)^2: 6.1291  KL_z_aux9: 2.7894997596740723 KL_z_aux10: 0.03478245064616203 KL_c3: 0.016664067283272743 KL_k3: 1.2853764295578003 KL_init_x3: 0.016692079603672028  KL_init_v3: 0.012210432440042496
# ====> Epoch: 3989  Training (rec. err.)^2: 18.0473  KL_z_aux9: 2.7479135990142822 KL_z_aux10: 0.03316434472799301 KL_m3: 1.7533800601959229  KL_c3: 0.04684921354055405 KL_k3: 1.2009539604187012 KL_init_x3: 0.046389881521463394  KL_init_v3: 0.04497634992003441
# ====> Epoch: 3989  Validation (rec. err.)^2: 6.2660  KL_z_aux9: 2.799901008605957 KL_z_aux10: 0.03513738885521889 KL_c3: 0.01563764177262783 KL_k3: 1.2785215377807617 KL_init_x3: 0.0161576084792614  KL_init_v3: 0.011535318568348885
# ====> Epoch: 3990  Training (rec. err.)^2: 17.8729  KL_z_aux9: 2.7332966327667236 KL_z_aux10: 0.03435826301574707 KL_m3: 1.683622121810913  KL_c3: 0.04880331829190254 KL_k3: 1.2063196897506714 KL_init_x3: 0.04294436797499657  KL_init_v3: 0.04614173248410225
# ====> Epoch: 3990  Validation (rec. err.)^2: 6.3238  KL_z_aux9: 2.811527967453003 KL_z_aux10: 0.035335320979356766 KL_c3: 0.014849127270281315 KL_k3: 1.2783637046813965 KL_init_x3: 0.015852726995944977  KL_init_v3: 0.011006071232259274
# ====> Epoch: 3991  Training (rec. err.)^2: 18.1068  KL_z_aux9: 2.733459711074829 KL_z_aux10: 0.0333060696721077 KL_m3: 1.6935328245162964  KL_c3: 0.04538484290242195 KL_k3: 1.1980327367782593 KL_init_x3: 0.046710871160030365  KL_init_v3: 0.04888772964477539
# ====> Epoch: 3991  Validation (rec. err.)^2: 6.5990  KL_z_aux9: 2.8162295818328857 KL_z_aux10: 0.03543596714735031 KL_c3: 0.014309877529740334 KL_k3: 1.2843338251113892 KL_init_x3: 0.01555129885673523  KL_init_v3: 0.010549995116889477
# ====> Epoch: 3992  Training (rec. err.)^2: 16.9418  KL_z_aux9: 2.757721424102783 KL_z_aux10: 0.03569064661860466 KL_m3: 1.6622618436813354  KL_c3: 0.0428728312253952 KL_k3: 1.1943297386169434 KL_init_x3: 0.04536513611674309  KL_init_v3: 0.04573514685034752
# ====> Epoch: 3992  Validation (rec. err.)^2: 6.2471  KL_z_aux9: 2.818791151046753 KL_z_aux10: 0.03557959944009781 KL_c3: 0.017103305086493492 KL_k3: 1.3082305192947388 KL_init_x3: 0.0186826940625906  KL_init_v3: 0.012941607274115086
# ====> Epoch: 3993  Training (rec. err.)^2: 16.9800  KL_z_aux9: 2.7275993824005127 KL_z_aux10: 0.03447265177965164 KL_m3: 1.7959251403808594  KL_c3: 0.0472082756459713 KL_k3: 1.2528468370437622 KL_init_x3: 0.04996451735496521  KL_init_v3: 0.046331118792295456
# ====> Epoch: 3993  Validation (rec. err.)^2: 6.4418  KL_z_aux9: 2.828159809112549 KL_z_aux10: 0.03559612110257149 KL_c3: 0.01443840004503727 KL_k3: 1.3116525411605835 KL_init_x3: 0.01583775319159031  KL_init_v3: 0.010943829081952572
# ====> Epoch: 3994  Training (rec. err.)^2: 18.2498  KL_z_aux9: 2.7659220695495605 KL_z_aux10: 0.03392428904771805 KL_m3: 1.7205959558486938  KL_c3: 0.045933954417705536 KL_k3: 1.2156518697738647 KL_init_x3: 0.0471150241792202  KL_init_v3: 0.04406469315290451
# ====> Epoch: 3994  Validation (rec. err.)^2: 6.8761  KL_z_aux9: 2.8468575477600098 KL_z_aux10: 0.03571189567446709 KL_c3: 0.014604921452701092 KL_k3: 1.3213459253311157 KL_init_x3: 0.016386380419135094  KL_init_v3: 0.011614994145929813
# ====> Epoch: 3995  Training (rec. err.)^2: 18.9635  KL_z_aux9: 2.7680256366729736 KL_z_aux10: 0.034170329570770264 KL_m3: 1.7601709365844727  KL_c3: 0.043697699904441833 KL_k3: 1.2558708190917969 KL_init_x3: 0.04971620440483093  KL_init_v3: 0.04587521031498909
# ====> Epoch: 3995  Validation (rec. err.)^2: 6.6831  KL_z_aux9: 2.868760585784912 KL_z_aux10: 0.0354207344353199 KL_c3: 0.020388372242450714 KL_k3: 1.3596081733703613 KL_init_x3: 0.022737668827176094  KL_init_v3: 0.017374390736222267
# ====> Epoch: 3996  Training (rec. err.)^2: 17.1356  KL_z_aux9: 2.8295609951019287 KL_z_aux10: 0.035164982080459595 KL_m3: 1.8254382610321045  KL_c3: 0.047208573669195175 KL_k3: 1.2724614143371582 KL_init_x3: 0.051730792969465256  KL_init_v3: 0.04358487203717232
# ====> Epoch: 3996  Validation (rec. err.)^2: 6.3112  KL_z_aux9: 2.867901086807251 KL_z_aux10: 0.034984033554792404 KL_c3: 0.016066819429397583 KL_k3: 1.3498568534851074 KL_init_x3: 0.01759122870862484  KL_init_v3: 0.013368097133934498
# ====> Epoch: 3997  Training (rec. err.)^2: 17.2063  KL_z_aux9: 2.7899672985076904 KL_z_aux10: 0.03337329253554344 KL_m3: 1.7536042928695679  KL_c3: 0.04283188655972481 KL_k3: 1.2668896913528442 KL_init_x3: 0.04472602158784866  KL_init_v3: 0.041221048682928085
# ====> Epoch: 3997  Validation (rec. err.)^2: 6.9279  KL_z_aux9: 2.8462748527526855 KL_z_aux10: 0.03489946201443672 KL_c3: 0.013341015204787254 KL_k3: 1.3495051860809326 KL_init_x3: 0.014009314589202404  KL_init_v3: 0.010754202492535114
# ====> Epoch: 3998  Training (rec. err.)^2: 17.0530  KL_z_aux9: 2.749051809310913 KL_z_aux10: 0.034145988523960114 KL_m3: 1.69254732131958  KL_c3: 0.041973356157541275 KL_k3: 1.2997713088989258 KL_init_x3: 0.040972884744405746  KL_init_v3: 0.04461246728897095
# ====> Epoch: 3998  Validation (rec. err.)^2: 6.3319  KL_z_aux9: 2.819589138031006 KL_z_aux10: 0.03473224490880966 KL_c3: 0.01617087796330452 KL_k3: 1.3606348037719727 KL_init_x3: 0.01701509952545166  KL_init_v3: 0.013463136740028858
# ====> Epoch: 3999  Training (rec. err.)^2: 17.3659  KL_z_aux9: 2.7222280502319336 KL_z_aux10: 0.03403440862894058 KL_m3: 1.7353298664093018  KL_c3: 0.0438665933907032 KL_k3: 1.2868269681930542 KL_init_x3: 0.047518640756607056  KL_init_v3: 0.044852714985609055
# ====> Epoch: 3999  Validation (rec. err.)^2: 6.2466  KL_z_aux9: 2.8203630447387695 KL_z_aux10: 0.03448890894651413 KL_c3: 0.015078063122928143 KL_k3: 1.3567794561386108 KL_init_x3: 0.015893930569291115  KL_init_v3: 0.01237522903829813
# ====> Epoch: 4000  Training (rec. err.)^2: 17.5755  KL_z_aux9: 2.728320598602295 KL_z_aux10: 0.03462068364024162 KL_m3: 1.7169756889343262  KL_c3: 0.04190557077527046 KL_k3: 1.2842847108840942 KL_init_x3: 0.045374855399131775  KL_init_v3: 0.04731445014476776
# ====> Epoch: 4000  Validation (rec. err.)^2: 7.3834  KL_z_aux9: 2.839853048324585 KL_z_aux10: 0.03459399938583374 KL_c3: 0.011907998472452164 KL_k3: 1.3390315771102905 KL_init_x3: 0.012051359750330448  KL_init_v3: 0.009096468798816204
#
# end training
# best model saved

# %% [markdown]
# # Postprocessing

# %%
# load displacement 3 model
model_dis3 = VAE_dis3(config_dis3)
model_dis3.load_state_dict(torch.load('best model_dis3.pt'))
model_dis3.eval()
print("model_loaded")
# Out:
# model_loaded

# %%
pn_samples = (5000,1)
pv_samples = (5000,1)

# %%
range_pm1= [50,2.5]  
range_pm2= [50,2.5]  
range_pm3= [30,1.5]  

range_pc1= [25,2.5] 
range_pc2= [25,2.5] 
range_pc3= [20,2] 

range_pk1= [1000,150]
range_pk2= [1000,150]
range_pk3= [500,75]

range_px1= [0.1,0.01]
range_px2= [0.1,0.01]
range_px3= [0.2,0.02]

range_pv1= [0.1,0.01]
range_pv2= [0.1,0.01]
range_pv3= [0.2,0.02]

# %%
bound_px1 = [range_px1[0]-3*range_px1[1],range_px1[0]+3*range_px1[1]]
bound_pv1 = [range_pv1[0]-3*range_pv1[1],range_pv1[0]+3*range_pv1[1]]
bound_pm1 = [range_pm1[0]-3*range_pm1[1], range_pm1[0]+3*range_pm1[1]]
bound_pc1 = [range_pc1[0]-3*range_pc1[1], range_pc1[0]+3*range_pc1[1]]
bound_pk1 = [range_pk1[0]-3*range_pk1[1], range_pk1[0]+3*range_pk1[1]]

bound_px2 = [range_px2[0]-3*range_px2[1],range_px2[0]+3*range_px2[1]]
bound_pv2 = [range_pv2[0]-3*range_pv2[1],range_pv2[0]+3*range_pv2[1]]
bound_pm2 = [range_pm2[0]-3*range_pm2[1], range_pm2[0]+3*range_pm2[1]]
bound_pc2 = [range_pc2[0]-3*range_pc2[1], range_pc2[0]+3*range_pc2[1]]
bound_pk2 = [range_pk2[0]-3*range_pk2[1], range_pk2[0]+3*range_pk2[1]]

bound_px3 = [range_px3[0]-3*range_px3[1],range_px3[0]+3*range_px3[1]]
bound_pv3 = [range_pv3[0]-3*range_pv3[1],range_pv3[0]+3*range_pv3[1]]
bound_pm3 = [range_pm3[0]-3*range_pm3[1], range_pm3[0]+3*range_pm3[1]]
bound_pc3 = [range_pc3[0]-3*range_pc3[1], range_pc3[0]+3*range_pc3[1]]
bound_pk3 = [range_pk3[0]-3*range_pk3[1], range_pk3[0]+3*range_pk3[1]]

# %%
px1_a,px1_b = (bound_px1[0]-range_px1[0])/range_px1[1] , (bound_px1[1]-range_px1[0])/range_px1[1]
pv1_a,pv1_b = (bound_pv1[0]-range_pv1[0])/range_pv1[1] , (bound_pv1[1]-range_pv1[0])/range_pv1[1]
pm1_a,pm1_b = (bound_pm1[0]-range_pm1[0])/range_pm1[1] , (bound_pm1[1]-range_pm1[0])/range_pm1[1]
pc1_a,pc1_b = (bound_pc1[0]-range_pc1[0])/range_pc1[1] , (bound_pc1[1]-range_pc1[0])/range_pc1[1]
pk1_a,pk1_b = (bound_pk1[0]-range_pk1[0])/range_pk1[1] , (bound_pk1[1]-range_pk1[0])/range_pk1[1]

px2_a,px2_b = (bound_px2[0]-range_px2[0])/range_px2[1] , (bound_px2[1]-range_px2[0])/range_px2[1]
pv2_a,pv2_b = (bound_pv2[0]-range_pv2[0])/range_pv2[1] , (bound_pv2[1]-range_pv2[0])/range_pv2[1]
pm2_a,pm2_b = (bound_pm2[0]-range_pm2[0])/range_pm2[1] , (bound_pm2[1]-range_pm2[0])/range_pm2[1]
pc2_a,pc2_b = (bound_pc2[0]-range_pc2[0])/range_pc2[1] , (bound_pc2[1]-range_pc2[0])/range_pc2[1]
pk2_a,pk2_b = (bound_pk2[0]-range_pk2[0])/range_pk2[1] , (bound_pk2[1]-range_pk2[0])/range_pk2[1]

px3_a,px3_b = (bound_px3[0]-range_px3[0])/range_px3[1] , (bound_px3[1]-range_px3[0])/range_px3[1]
pv3_a,pv3_b = (bound_pv3[0]-range_pv3[0])/range_pv3[1] , (bound_pv3[1]-range_pv3[0])/range_pv3[1]
pm3_a,pm3_b = (bound_pm3[0]-range_pm3[0])/range_pm3[1] , (bound_pm3[1]-range_pm3[0])/range_pm3[1]
pc3_a,pc3_b = (bound_pc3[0]-range_pc3[0])/range_pc3[1] , (bound_pc3[1]-range_pc3[0])/range_pc3[1]
pk3_a,pk3_b = (bound_pk3[0]-range_pk3[0])/range_pk3[1] , (bound_pk3[1]-range_pk3[0])/range_pk3[1]

# %%
x1_vec = torch.Tensor(stats.truncnorm.rvs(px1_a,px1_b,loc=range_px1[0], scale=range_px1[1], size=pn_samples ))
v1_vec = torch.Tensor(stats.truncnorm.rvs(pv1_a,pv1_b,loc=range_pv1[0], scale=range_pv1[1], size=pn_samples ))
x2_vec = torch.Tensor(stats.truncnorm.rvs(px2_a,px2_b,loc=range_px2[0], scale=range_px2[1], size=pn_samples ))
v2_vec = torch.Tensor(stats.truncnorm.rvs(pv2_a,pv2_b,loc=range_pv2[0], scale=range_pv2[1], size=pn_samples ))
x3_vec = torch.Tensor(stats.truncnorm.rvs(px3_a,px3_b,loc=range_px3[0], scale=range_px3[1], size=pn_samples ))
v3_vec = torch.Tensor(stats.truncnorm.rvs(pv3_a,pv3_b,loc=range_pv3[0], scale=range_pv3[1], size=pn_samples ))


m1_vec = torch.Tensor(stats.truncnorm.rvs(pm1_a,pm1_b,loc=range_pm1[0], scale=range_pm1[1], size=pn_samples ))
m2_vec = torch.Tensor(stats.truncnorm.rvs(pm2_a,pm2_b,loc=range_pm2[0], scale=range_pm2[1], size=pn_samples ))
m3_vec = torch.Tensor(stats.truncnorm.rvs(pm3_a,pm3_b,loc=range_pm3[0], scale=range_pm3[1], size=pn_samples ))

c1_vec = torch.Tensor(stats.truncnorm.rvs(pc1_a,pc1_b,loc=range_pc1[0], scale=range_pc1[1], size=pn_samples ))
c2_vec = torch.Tensor(stats.truncnorm.rvs(pc2_a,pc2_b,loc=range_pc2[0], scale=range_pc2[1], size=pn_samples ))
c3_vec = torch.Tensor(stats.truncnorm.rvs(pc3_a,pc3_b,loc=range_pc3[0], scale=range_pc3[1], size=pn_samples ))

k1_vec = torch.Tensor(stats.truncnorm.rvs(pk1_a,pk1_b,loc=range_pk1[0], scale=range_pk1[1], size=pn_samples ))
k2_vec = torch.Tensor(stats.truncnorm.rvs(pk2_a,pk2_b,loc=range_pk2[0], scale=range_pk2[1], size=pn_samples ))
k3_vec = torch.Tensor(stats.truncnorm.rvs(pk3_a,pk3_b,loc=range_pk3[0], scale=range_pk3[1], size=pn_samples ))


z_aux1 = torch.normal(mean=0, std=1, size= pv_samples)
z_aux2 = torch.normal(mean=0, std=1, size= pv_samples)
z_aux5 = torch.normal(mean=0, std=1, size= pv_samples)
z_aux6 = torch.normal(mean=0, std=1, size= pv_samples)
z_aux9 = torch.normal(mean=0, std=1, size= pv_samples)
z_aux10 = torch.normal(mean=0, std=1, size= pv_samples)

# %%
#scaling
m1_vecs = (m1_vec - m1_o_min)/(m1_o_max - m1_o_min)
c1_vecs = (c1_vec - c1_o_min)/(c1_o_max - c1_o_min)
k1_vecs = (k1_vec - k1_o_min)/(k1_o_max - k1_o_min)
x1_vecs = (x1_vec - x1_o_min)/(x1_o_max - x1_o_min)
v1_vecs = (v1_vec - v1_o_min)/(v1_o_max - v1_o_min)

m2_vecs = (m2_vec - m2_o_min)/(m2_o_max - m2_o_min)
c2_vecs = (c2_vec - c2_o_min)/(c2_o_max - c2_o_min)
k2_vecs = (k2_vec - k2_o_min)/(k2_o_max - k2_o_min)
x2_vecs = (x2_vec - x2_o_min)/(x2_o_max - x2_o_min)
v2_vecs = (v2_vec - v2_o_min)/(v2_o_max - v2_o_min)

m3_vecs = (m3_vec - m3_o_min)/(m3_o_max - m3_o_min)
c3_vecs = (c3_vec - c3_o_min)/(c3_o_max - c3_o_min)
k3_vecs = (k3_vec - k3_o_min)/(k3_o_max - k3_o_min)
x3_vecs = (x3_vec - x3_o_min)/(x3_o_max - x3_o_min)
v3_vecs = (v3_vec - v3_o_min)/(v3_o_max - v3_o_min)

# %%
# generate displacement 3 from learned model
from torchdiffeq import odeint
with torch.no_grad():
    cf_x3 = []
    cf_x3, _ = model_dis3.decode(m3_vecs,c3_vecs,k3_vecs, x3_vecs,v3_vecs, z_aux9, z_aux10)
    cf_x3 = cf_x3.numpy()
    cfx3_phy_only = model_dis3.generate_physonly(m3_vecs,c3_vecs,k3_vecs,x3_vecs,v3_vecs,)
    cfx3_phy_only = cfx3_phy_only.numpy()

# %%
# save data
def save_data(name,data):
  np.savetxt('data_{}.txt'.format(name),data)
  print("saved data")

    # save true parameters
  
  # np.savetxt('true_params_{}.txt'.format('m1_vec'),m1_vec)
  # np.savetxt('true_params_{}.txt'.format('c1_vec'),c1_vec)
  # np.savetxt('true_params_{}.txt'.format('k1_vec'),k1_vec)
  # np.savetxt('true_params_{}.txt'.format('x1_vec'),x1_vec)
  # np.savetxt('true_params_{}.txt'.format('v1_vec'),v1_vec)


  # np.savetxt('true_params_{}.txt'.format('m2_vec'),m2_vec)
  # np.savetxt('true_params_{}.txt'.format('c2_vec'),c2_vec)
  # np.savetxt('true_params_{}.txt'.format('k2_vec'),k2_vec)
  # np.savetxt('true_params_{}.txt'.format('x2_vec'),x2_vec)
  # np.savetxt('true_params_{}.txt'.format('v2_vec'),v2_vec)

  # np.savetxt('true_params_{}.txt'.format('m3_vec'),m3_vec)
  # np.savetxt('true_params_{}.txt'.format('c3_vec'),c3_vec)
  # np.savetxt('true_params_{}.txt'.format('k3_vec'),k3_vec)
  # np.savetxt('true_params_{}.txt'.format('x3_vec'),x3_vec)
  # np.savetxt('true_params_{}.txt'.format('v3_vec'),v3_vec)

  # print('saved true parameters')

# %%
save_data('phy_only_3', cfx3_phy_only[:,:,0])
# Out:
# saved data

# %%
# Unscaling predicted data
# cf_x3 = cf_x3 *(data_train_dis3_us_max- data_train_dis3_us_min) + data_train_dis3_us_min

# %% [markdown]
# Generating true data with z_phy1, z_phy2, z_phy3, z_phy and z_phy5 as physics parameters

# %%
import numpy as np
import scipy.stats as stats
from torchdiffeq import odeint
from scipy.stats import truncnorm
import torch

def generate_traj(init_cond,m1,m2,m3,c1,c2,c3,k1,k2,k3, alpha,gamma,omega, dt, len_episode):

    def ode_sys(t, X):
        x1,v1=torch.Tensor([X[0]]),torch.Tensor([X[1]])
        x2,v2=torch.Tensor([X[2]]),torch.Tensor([X[3]])
        x3,v3=torch.Tensor([X[4]]),torch.Tensor([X[5]])


        dx1_dt = v1
        dv1_dt = torch.Tensor([(gamma*(torch.cos(omega*t)) -c1*v1 + k1*x1 -c2*(v1-v2) -k2*(x1-x2) -alpha*(x1**3)) /m1])

        dx2_dt = v2
        dv2_dt = torch.Tensor([(gamma*(torch.cos(omega*t)) -c2*(v2-v1) - k2*(x2-x1) -c3*(v2-v3) - k3*(x2-x3) ) /m2])

        dx3_dt = v3
        dv3_dt = torch.Tensor([(gamma*(torch.cos(omega*t)) -c3*(v3-v2) - k3*(x3-x2)) /m3])

        

        return torch.cat([dx1_dt, dv1_dt, dx2_dt, dv2_dt,dx3_dt, dv3_dt])

        
    t = torch.Tensor(np.linspace(0.0, dt*(len_episode-1), len_episode))


    #num_sol = odeint(ode_sys, torch.cat([x_init, dxdt_init]), torch.Tensor(t_space)).numpy()
    
    sol = odeint(ode_sys,init_cond,t, method = 'euler').numpy()
    
    return t, sol

# %%
n = 5000
dt = config_dis3['dt']
dim_t = config_dis3['dim_t']

cf_x_true_dis1 = np.empty((n, dim_t))
cf_x_true_vel1 = np.empty((n, dim_t))
cf_x_true_dis2 = np.empty((n, dim_t))
cf_x_true_vel2 = np.empty((n, dim_t))
cf_x_true_dis3 = np.empty((n, dim_t))
cf_x_true_vel3 = np.empty((n, dim_t))
#generate_traj_true(x_vec[i] ,x_vec[i],m_vec[i],c_vec[i], k_vec[i],alpha, gamma, omega, dt, dim_t) 
for i in range(n):
    init_cond = torch.cat([x1_vec[i],v1_vec[i],x2_vec[i],v2_vec[i],x3_vec[i],v3_vec[i]])
    m1 = m1_vec[i]
    m2 = m2_vec[i]
    m3 = m3_vec[i]
    c1 = c1_vec[i]
    c2 = c2_vec[i]
    c3 = c3_vec[i]
    k1 = k1_vec[i]
    k2 = k2_vec[i]
    k3 = k3_vec[i]
    alpha = config_dis3['alpha']
    gamma = config_dis3['gamma']
    omega = config_dis3['omega']


    t, tmp = generate_traj(init_cond,m1,m2,m3,c1,c2,c3,k1,k2,k3,
                                        alpha,gamma,omega, dt, dim_t) 

    cf_x_true_dis1[i] = tmp[:,0]

    cf_x_true_dis2[i] = tmp[:,2]

    cf_x_true_dis3[i] = tmp[:,4]

# %%
# save true data
def save_data(name,data):
  np.savetxt('data_{}.txt'.format(name),data)
  print("saved data")

# %%
save_data("true_dis3",cf_x_true_dis3)
# Out:
# saved data

# %% [markdown]
# # Displacement_3 prediction

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# show
idx =0
plt.figure()
figure(figsize=(20, 15), dpi=80)

for i in range(20):
    
    plt.subplot(5,4,i+1)
    plt.plot(t,cf_x3[i,:], 'r',linewidth=3,label="Prediction_displacement")
    plt.plot(t,cf_x_true_dis3[i,:], 'b',linestyle='dashed',linewidth=3,label="True_displacement")
    plt.plot(t,cfx3_phy_only[:,i,0], 'g',label="Phy_only_displacement")
    
    #plt.ylim([-2.0, 2.0])
plt.legend(loc='upper right',fontsize=7)
plt.show()

# %%
# calculate mean of n displacement:
# pred
cf_x3_mean = []
cf_x3_T = cf_x3.T
for x in cf_x3_T:
   #print(x.shape)
    cf_x3_mean.append(x.mean())

# true
cf_x3_true_dis_mean =[]
cf_x3_true_dis_T = cf_x_true_dis3.T
for y in cf_x3_true_dis_T:
   #print(x.shape)
    cf_x3_true_dis_mean.append(y.mean())

# phy only
cf_x3_phy_dis_mean =[]
for z in cfx3_phy_only[:,:,0]:
   #print(x.shape)
    cf_x3_phy_dis_mean.append(z.mean())

# %%
# calculate std of n displacement

#pred
cf_x3_std = []
cf_x3_T = cf_x3.T
for x in cf_x3_T:
   #print(x.shape)
    cf_x3_std.append(x.var())

#true
cf_x3_true_dis_std =[]
cf_x3_true_dis_T = cf_x_true_dis3.T
for y in cf_x3_true_dis_T:
   #print(x.shape)
    cf_x3_true_dis_std.append(y.var())

# phy only
cf_x3_phy_dis_std =[]
for z in cfx3_phy_only[:,:,0]:
   #print(x.shape)
    cf_x3_phy_dis_std.append(z.var())

# %%
from matplotlib import pyplot as plt
import numpy as np
plt.figure()
figure(figsize=(12, 7), dpi=80)


# Plot the means
plt.plot(t, cf_x3_mean, color='red',linewidth=4,label="Predicted(mean)")
plt.plot(t,cf_x3_true_dis_mean, color='blue',linestyle='--', linewidth = 4,markevery=10,marker='o',markersize=8,alpha=0.8, label="Ground Truth(mean)") #
plt.plot(t,cf_x3_phy_dis_mean, 'g',linewidth = 3,linestyle=':',label="Physics only(mean)")



# # Plot the confidence interval
#plt.fill_between(t, (cf_x2_mean-ci_x), (cf_x2_mean+ci_x), color='blue', alpha=0.1)
plt.legend(loc='upper right',fontsize=18)
plt.xlabel("Time(sec)",fontsize = 30, labelpad=20)
plt.ylabel("$y_3$(m)",fontsize = 30, labelpad=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.rcParams["axes.edgecolor"] = "black"
# plt.rcParams["axes.linewidth"] = 3.0
plt.show()

# %%
plt.figure()
figure(figsize=(12,7), dpi=80)
#Plot the variance

plt.plot(t, cf_x3_std, color='red',linewidth =4,label="Predicted(variance)")
plt.plot(t,cf_x3_true_dis_std,color='blue',linestyle='--', linewidth = 4,markevery=10,marker='o',markersize=8,alpha=0.8,label="Ground Truth(variance)")
plt.plot(t,cf_x3_phy_dis_std,color='green',linewidth = 3,linestyle=':',label="Physics only(Variance)")

plt.legend(loc='upper left',fontsize=16)
plt.xlabel("Time(sec)",fontsize = 30, labelpad=20)
plt.ylabel("$y_3$(m)",fontsize = 30, labelpad=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.rcParams["axes.edgecolor"] = "black"
# plt.rcParams["axes.linewidth"] = 3.0
plt.show()

# %%
import seaborn as sns
plt.figure()
figure(figsize=(10, 5), dpi=80)
sns.distplot(a=cf_x3[:,49], kde=True,bins=10,hist = False, kde_kws={"color": "r", "lw": 4})#, label = "Predicted")
sns.distplot(a=cf_x_true_dis3[:,49], kde=True,bins=10,hist = False, kde_kws={"color": "b","linestyle":"--", "lw":4,"marker":'o',"markevery":10,"markersize":8,"alpha":0.8})#, label= "Ground Truth")
sns.distplot(a=cfx3_phy_only[:,49], kde=True,bins=10,hist = False, kde_kws={"linestyle":":","color": "green","lw": 3})#, label= "Physics only")
plt.legend(loc='upper right',fontsize=10)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# No handles with labels found to put in legend.

# %%
import seaborn as sns
plt.figure()
figure(figsize=(12, 7), dpi=80)
sns.distplot(a=cf_x3[:,249], kde=True,bins=10,hist = False, kde_kws={"color": "r", "lw": 4}, label = "Predicted")
sns.distplot(a=cf_x_true_dis3[:,249], kde=True,bins=10,hist = False, kde_kws={"color": "b","linestyle":"--", "lw":4,"marker":'o',"markevery":10,"markersize":8,"alpha":0.8}, label= "Ground Truth")
sns.distplot(a=cfx3_phy_only[:,249], kde=True,bins=10,hist = False, kde_kws={"linestyle":":","color": "green","lw": 3}, label= "Physics only")
# plt.plot(t,cf_x2_phy_dis_std,color='white',alpha=0.01,label="Training samples:500")
# plt.plot(t,cf_x2_phy_dis_std,color='white',alpha=0.01,label="Time:2sec")
plt.legend(loc='upper right',fontsize=20)
plt.xlabel("$y_3$(m)",fontsize = 30, labelpad=20)
plt.ylabel("Density",fontsize = 30, labelpad=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.rcParams["axes.edgecolor"] = "black"
# plt.rcParams["axes.linewidth"] = 3.0
# plt.ylim([0, 1])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
